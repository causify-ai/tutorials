# %% [markdown]
# # Altair Bitcoin Dashboard Example
# This notebook demonstrates the complete usage of the `Altair_utils.py` module to generate an interactive Bitcoin dashboard using historical data and computed indicators.

# %%
from Altair_utils import fetch_kraken_data, get_combined_data, generate_dashboard
import altair as alt

# %%
# Getting historical data from Kraken
df_hist = fetch_kraken_data()

# %%
#Combining with live data (if live is running)
df_combined = get_combined_data()

# %%
#Generating dashboard chart object
chart = generate_dashboard(df_combined)

# %%
# Step 4: Displaying chart
chart
# Out:
# alt.VConcatChart(...)
