# %% [markdown]
# # 📊 Bitcoin API Usage Demo
# This notebook demonstrates how to use utility functions from `Altair_utils.py` to fetch historical data, stream live Coinbase data, and prepare it for visualization.

# %%
from Altair_utils import fetch_kraken_data, get_combined_data, generate_dashboard
import pandas as pd

# %%
# Fetch historical BTC data from Yahoo Finance
df = fetch_kraken_data()
df.head()
# Out:
#             timestamp      open      high       low     close     volume
# 0 2025-05-09 17:00:00  102484.4  102810.1  102352.2  102772.0  10.390852
# 1 2025-05-09 17:15:00  102772.1  103000.0  102772.1  102999.9   5.031551
# 2 2025-05-09 17:30:00  103000.0  103191.1  102999.9  103155.8   6.922418
# 3 2025-05-09 17:45:00  103155.8  103199.0  103121.2  103186.2  18.655403
# 4 2025-05-09 18:00:00  103186.2  103186.2  103029.7  103080.0   4.019356
