# %%
# Import Binance Data

# %%
from App.Falcon_API import BinanceWebSocketClient
import asyncio

async def process_trade(trade):
    print(trade)  # or POST to Falcon

client = BinanceWebSocketClient()
await client.listen(process_trade)
