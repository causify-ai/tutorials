# %%
pip install pandas requests python-dotenv matplotlib seaborn numpy
# Out:
# Requirement already satisfied: pandas in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: requests in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: python-dotenv in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: matplotlib in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (3.10.3)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: contourpy>=1.0.1 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from matplotlib) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /home/pradeep/.jupyterenv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 4.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run activecampaign_api.py
# Out:
#      type userid segmentid bounceid realcid sendid threadid seriesid formid  \
# 0   split      1         0       -1       0      3        0        0      0
# 1  single      1         0       -1       0      1        0        0      0
# 2  single      1         0       -1       0      2        0        0      0
#
#   basetemplateid  ... has_predictive_content message_id  \
# 0         100009  ...                      0          3
# 1         100006  ...                      0          5
# 2              0  ...                      0          7
#
#                                           screenshot campaign_message_id  \
# 0  //umd213.img-us3.com/_screenshot_/0578982e-f33...                   1
# 1  //umd213.img-us3.com/_screenshot_/66b6db6e-19f...                   3
# 2  //umd213.img-us3.com/_screenshot_/7e368148-60d...                   5
#
#   ed_version format                                              links id  \
# 0          3   mime  {'user': 'https://umd213.api-us1.com/api/3/cam...  1
# 1          3   mime  {'user': 'https://umd213.api-us1.com/api/3/cam...  5
# 2          3   mime  {'user': 'https://umd213.api-us1.com/api/3/cam...  6
#
#   user automation
# 0    1       None
# 1    1       None
# 2    1       None
#
# [3 rows x 110 columns]

# %%
# %run activecampaign_example.py
# Out:
# /home/pradeep/src/tutorials1/DATA605/Spring2025/projects/TutorTask149_Spring2025_Analyze_Email_Campaign_Performance_Over_Time_with_ActiveCampaign/activecampaign_example.py:56: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   combined_df.fillna(0, inplace=True)
# Saved: campaign_trends_plot.png
# Saved: engagement_by_weekday.png
# Saved: openrate_ctr_trends.png
# Top Performing Campaigns:
#                        opens  linkclicks  unsubscribes
# name
# UMD RecWell Notice      4434        1369             3
# Promo Blast             4373        1344             5
# Free Fries Friday       4325        1335             5
#  Career Hack Alert      4441        1287             2
# 50% Pro Discount        4261        1268             3
# Newsletter              4347        1267             2
# Weekly Update           4350        1266             8
# AI Tips Newsletter      4302        1260             4
# Job Alerts              4320        1223             4
# Terps Newsletter Test     20           8             0
# Saved: opens_heatmap.png
# Saved: moving_avg_trend.png
