# %% [markdown]
# # Bitcoin Price Prediction with TensorFlow: Example Notebook
#
# This notebook demonstrates how to use the utility functions from `bitcoin_utils.py` to:
# - Load and clean historical Bitcoin data.
# - Engineer technical features.
# - Prepare sequences for LSTM modeling.
# - Train a simple LSTM network to predict Bitcoin prices.
#
# We keep this example minimal and clean to illustrate usage of the provided API.

# %% [markdown]
# ### Setup & Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Imports
import sys
sys.path.append("..")  # if needed to import bitcoin_utils.py

import numpy as np
import matplotlib.pyplot as plt

from bitcoin_utils import (
    load_and_clean_csv,
    update_dataset_with_latest,
    technical_features,
    generate_sequences,
    build_lstm_model,
    train_lstm_model,
    fine_tune_model,
    plot_training_loss,
    predict_next_price,
    tune_lstm_model

)

# %% [markdown]
# ## Load and Clean Bitcoin Data
#
# We load the dataset from the CSV file and apply initial cleaning and formatting.

# %%
# Path to your dataset
csv_path = 'btc-usd-max.csv'  # Update path if needed

# Load and clean
df = load_and_clean_csv(csv_path)

# Show the head
df.head()
# Out:
# INFO:bitcoin_utils:Loading dataset from btc-usd-max.csv
# INFO:bitcoin_utils:Removed 100 anomalous rows based on z-score > 3.0
# INFO:bitcoin_utils:Dataset loaded: 4302 rows; columns: ['price', 'market_cap', 'total_volume']
#                             price    market_cap  total_volume
# snapped_at
# 2013-04-28 00:00:00+00:00  135.30  1.500518e+09           0.0
# 2013-04-29 00:00:00+00:00  141.96  1.575032e+09           0.0
# 2013-04-30 00:00:00+00:00  135.30  1.501657e+09           0.0
# 2013-05-01 00:00:00+00:00  117.00  1.298952e+09           0.0
# 2013-05-02 00:00:00+00:00  103.43  1.148668e+09           0.0

# %% [markdown]
# ## Update Dataset with Latest Data Point
#
# To ensure we are working with the most recent Bitcoin data, we can use the `update_dataset_with_latest()` function from `bitcoin_utils.py`.
#
# This function:
# - Fetches the latest market data from the CoinGecko API.
# - Appends the new data point to the existing dataset (if it’s not already present).
# - Keeps your CSV file up-to-date automatically.
#
# We then reload the updated dataset to continue working with the latest data.

# %%
update_dataset_with_latest(csv_path)

# Reload the updated dataset
df = load_and_clean_csv(csv_path)

# Confirm update
df.tail()
# Out:
# INFO:bitcoin_utils:Loading existing dataset from btc-usd-max.csv
# INFO:bitcoin_utils:Fetching latest data point from CoinGecko
# INFO:bitcoin_utils:Latest data point: {'snapped_at': Timestamp('2025-05-18 02:05:59+0000', tz='UTC'), 'price': 103291.22684882184, 'market_cap': 2051756290844.4033, 'total_volume': 17839908325.65489}
# INFO:bitcoin_utils:Appending new data point to the dataset.
# INFO:bitcoin_utils:Dataset updated and saved to btc-usd-max.csv
# INFO:bitcoin_utils:Loading dataset from btc-usd-max.csv
# INFO:bitcoin_utils:Removed 98 anomalous rows based on z-score > 3.0
# INFO:bitcoin_utils:Dataset loaded: 4305 rows; columns: ['price', 'market_cap', 'total_volume']
#                                   price    market_cap  total_volume
# snapped_at
# 2025-04-27 00:00:00+00:00  94644.066371  1.879132e+12  1.544539e+10
# 2025-04-28 00:00:00+00:00  93809.337820  1.862772e+12  1.592626e+10
# 2025-04-29 00:00:00+00:00  95030.606455  1.887067e+12  3.191381e+10
# 2025-04-30 00:00:00+00:00  94256.359463  1.870818e+12  2.588263e+10
# 2025-05-01 00:00:00+00:00  94235.753310  1.871350e+12  2.654170e+10

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# In this section, we explore the Bitcoin dataset to understand trends, patterns, and relationships between variables.

# %% [markdown]
# 1️⃣ Line Plot: Bitcoin Price Over Time

# %%
import matplotlib.pyplot as plt

# Plot Bitcoin price over time
plt.figure(figsize=(12,6))
df['price'].plot()
plt.title('Bitcoin Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# 2️⃣ Log Scale Price Plot
#
#
# Bitcoin price spans many orders of magnitude; a log plot can be insightful:

# %%
plt.figure(figsize=(12,6))
df['price'].plot(logy=True)
plt.title('Bitcoin Price (Log Scale)')
plt.xlabel('Date')
plt.ylabel('Price (Log USD)')
plt.show()

# %% [markdown]
# 3️⃣ Volume vs. Price (Scatter Plot)
#
# Shows relationship between trading volume and price.

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['market_cap'], df['price'], alpha=0.5, color='orange')
plt.title('Price vs Market Cap')
plt.xlabel('Market Cap')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# 5️⃣ Simple Moving Average (SMA)
#
# You can overlay moving averages to show trends.

# %%
df['SMA_30'] = df['price'].rolling(window=30).mean()
df['SMA_90'] = df['price'].rolling(window=90).mean()

plt.figure(figsize=(12,6))
df['price'].plot(label='Price')
df['SMA_30'].plot(label='30-Day SMA')
df['SMA_90'].plot(label='90-Day SMA')
plt.title('Bitcoin Price with 30 & 90-Day Moving Averages')
plt.legend()
plt.show()

# %% [markdown]
# ## Add Technical Features
#
# We enrich the dataset with useful features like returns, moving averages, and lag features.

# %%
# Add engineered features
df = technical_features(df)
features = ['price', 'returns', 'SMA_7', 'SMA_30', 'volatility_7', 'volatility_30', 'lag_1day']
X, y, scaler_X, scaler_y = generate_sequences(df, features=features, target='price', window_size=60)


# Now safely generate sequences


print("X shape:", X.shape)
print("y shape:", y.shape)
print("Any NaN in X?", np.isnan(X).any())
print("Any NaN in y?", np.isnan(y).any())
print("X min/max:", X.min(), X.max())
print("y min/max:", y.min(), y.max())


# Drop rows with NaNs in any input feature or the target
df = df.dropna(subset=features + ['price'])
# Check the result
df.tail()
# Out:
# INFO:bitcoin_utils:Adding technical feature columns
# INFO:bitcoin_utils:Feature engineering complete
# INFO:bitcoin_utils:Generating sequences using features ['price', 'returns', 'SMA_7', 'SMA_30', 'volatility_7', 'volatility_30', 'lag_1day'] and target 'price'
# INFO:bitcoin_utils:Generated 4245 sequences with shape (60, 7)
# X shape: (4245, 60, 7)
# y shape: (4245, 1)
# Any NaN in X? True
# Any NaN in y? False
# X min/max: nan nan
# y min/max: 0.0 0.9999999999999999
#                                   price    market_cap  total_volume  \
# snapped_at
# 2025-04-27 00:00:00+00:00  94644.066371  1.879132e+12  1.544539e+10
# 2025-04-28 00:00:00+00:00  93809.337820  1.862772e+12  1.592626e+10
# 2025-04-29 00:00:00+00:00  95030.606455  1.887067e+12  3.191381e+10
# 2025-04-30 00:00:00+00:00  94256.359463  1.870818e+12  2.588263e+10
# 2025-05-01 00:00:00+00:00  94235.753310  1.871350e+12  2.654170e+10
#
#                                  SMA_30        SMA_90   returns         SMA_7  \
# snapped_at
# 2025-04-27 00:00:00+00:00  84944.749173  87036.275788 -0.001362  91856.689034
# 2025-04-28 00:00:00+00:00  85259.744795  87228.045971 -0.008820  93104.713659
# 2025-04-29 00:00:00+00:00  85671.459258  87432.494639  0.013019  94187.365011
# 2025-04-30 00:00:00+00:00  86068.125203  87585.712894 -0.008147  94284.535522
# 2025-05-01 00:00:00+00:00  86458.847192  87647.916597 -0.000219  94374.578522
#
#                            volatility_7  volatility_30      lag_1day
# snapped_at
# 2025-04-27 00:00:00+00:00   3910.916209    4735.202649  94773.112006
# 2025-04-28 00:00:00+00:00   2538.545528    5001.737256  94644.066371
# 2025-04-29 00:00:00+00:00    607.832944    5282.466157  93809.337820
# 2025-04-30 00:00:00+00:00    544.956639    5468.465915  95030.606455
# 2025-05-01 00:00:00+00:00    459.408665    5622.364710  94256.359463

# %%
# Generate sequences for modeling
X, y, scaler_X, scaler_y = generate_sequences(df, features=features, target='price', window_size=60)
# Out:
# INFO:bitcoin_utils:Generating sequences using features ['price', 'returns', 'SMA_7', 'SMA_30', 'volatility_7', 'volatility_30', 'lag_1day'] and target 'price'
# INFO:bitcoin_utils:Generated 4216 sequences with shape (60, 7)

# %% [markdown]
# ## Build LSTM Model
#
# We build a simple LSTM model to predict Bitcoin prices based on historical data.

# %% [markdown]
# While the project documentation refers to an RNN architecture broadly, we chose to implement an LSTM (Long Short-Term Memory) model — a more advanced form of RNN — to better capture long-term dependencies in Bitcoin price trends. LSTM networks are specifically designed to overcome the vanishing gradient problem, making them highly effective for financial time series forecasting.

# %%
# Split data into train/test sets (e.g., 80% train, 20% test)
split = int(0.8 * len(X))
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# %% [markdown]
# ## Hyperparameter Tuning with KerasTuner
#
# We use the `tune_lstm_model()` utility to search for the best:
# - Number of LSTM units in each layer
# - Dropout rates
# - Validation loss over multiple trials
#
# This keeps the notebook clean while allowing reproducible tuning.

# %%
# Tune hyperparameters
best_model, best_hps, history = tune_lstm_model(X_train, y_train, X_test, y_test)
# Out:
# INFO:tensorflow:Oracle triggered exit
# Trial 5 Complete [00h 00m 35s]
# val_loss: 0.0025394076947122812
#
# Best val_loss So Far: 0.000986884580925107
# Total elapsed time: 00h 02m 56s
# Epoch 1/20
# 106/106 [==============================] - 5s 34ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 2/20
# 106/106 [==============================] - 3s 30ms/step - loss: 9.3528e-04 - val_loss: 9.7211e-04
# Epoch 3/20
# 106/106 [==============================] - 5s 48ms/step - loss: 9.2303e-04 - val_loss: 0.0014
# Epoch 4/20
# 106/106 [==============================] - 3s 29ms/step - loss: 8.4487e-04 - val_loss: 0.0010
# Epoch 5/20
# 106/106 [==============================] - 3s 29ms/step - loss: 7.4891e-04 - val_loss: 0.0033
# Epoch 6/20
# 106/106 [==============================] - 3s 28ms/step - loss: 7.3980e-04 - val_loss: 0.0027
# Epoch 7/20
# 106/106 [==============================] - 3s 28ms/step - loss: 8.2946e-04 - val_loss: 0.0012
# Epoch 8/20
# 106/106 [==============================] - 3s 29ms/step - loss: 7.7169e-04 - val_loss: 0.0046
# Epoch 9/20
# 106/106 [==============================] - 3s 29ms/step - loss: 6.9588e-04 - val_loss: 0.0030
# Epoch 10/20
# 106/106 [==============================] - 3s 29ms/step - loss: 7.5279e-04 - val_loss: 0.0012
# Epoch 11/20
# 106/106 [==============================] - 3s 30ms/step - loss: 7.1116e-04 - val_loss: 0.0016
# Epoch 12/20
# 106/106 [==============================] - 3s 30ms/step - loss: 7.1091e-04 - val_loss: 0.0019
# Epoch 13/20
# 106/106 [==============================] - 3s 31ms/step - loss: 7.4353e-04 - val_loss: 0.0019
# Epoch 14/20
# 106/106 [==============================] - 5s 31ms/step - loss: 6.3982e-04 - val_loss: 0.0017
# Epoch 15/20
# 106/106 [==============================] - 3s 30ms/step - loss: 6.7309e-04 - val_loss: 6.9627e-04
# Epoch 16/20
# 106/106 [==============================] - 3s 29ms/step - loss: 7.2598e-04 - val_loss: 0.0032
# Epoch 17/20
# 106/106 [==============================] - 3s 29ms/step - loss: 6.7464e-04 - val_loss: 6.0244e-04
# Epoch 18/20
# 106/106 [==============================] - 3s 30ms/step - loss: 6.2745e-04 - val_loss: 0.0012
# Epoch 19/20
# 106/106 [==============================] - 3s 30ms/step - loss: 7.2145e-04 - val_loss: 6.7601e-04
# Epoch 20/20
# 106/106 [==============================] - 3s 30ms/step - loss: 7.3649e-04 - val_loss: 8.6948e-04

# %%
print("Best Hyperparameters Found:")
print(f"LSTM Layer 1 Units: {best_hps.get('lstm_units_1')}")
print(f"Dropout Layer 1: {best_hps.get('dropout_1')}")
print(f"LSTM Layer 2 Units: {best_hps.get('lstm_units_2')}")
print(f"Dropout Layer 2: {best_hps.get('dropout_2')}")
# Out:
# Best Hyperparameters Found:
# LSTM Layer 1 Units: 64
# Dropout Layer 1: 0.2
# LSTM Layer 2 Units: 48
# Dropout Layer 2: 0.4

# %% [markdown]
# ## Train LSTM Model

# %%
model = build_lstm_model(input_shape=(X_train.shape[1], X_train.shape[2]))
model, history = train_lstm_model(model, X_train, y_train, X_test, y_test)
#  Save the model so the scheduler can fine-tune and predict with it
model.save("models/final_lstm_model.h5")
# Out:
# INFO:bitcoin_utils:Building LSTM model with input shape (60, 7)
# INFO:bitcoin_utils:Training LSTM model for 50 epochs with batch size 32
# Epoch 1/50
# 106/106 [==============================] - 6s 41ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 2/50
# 106/106 [==============================] - 4s 38ms/step - loss: 9.7248e-04 - val_loss: 0.0010
# Epoch 3/50
# 106/106 [==============================] - 6s 36ms/step - loss: 8.4904e-04 - val_loss: 9.8044e-04
# Epoch 4/50
# 106/106 [==============================] - 4s 36ms/step - loss: 6.9350e-04 - val_loss: 0.0016
# Epoch 5/50
# 106/106 [==============================] - 4s 38ms/step - loss: 7.3389e-04 - val_loss: 0.0012
# Epoch 6/50
# 106/106 [==============================] - 4s 35ms/step - loss: 6.4487e-04 - val_loss: 0.0013
# Epoch 7/50
# 106/106 [==============================] - 4s 35ms/step - loss: 6.2259e-04 - val_loss: 0.0014
# Epoch 8/50
# 106/106 [==============================] - 4s 35ms/step - loss: 5.9956e-04 - val_loss: 7.6031e-04
# Epoch 9/50
# 106/106 [==============================] - 4s 36ms/step - loss: 6.8532e-04 - val_loss: 0.0016
# Epoch 10/50
# 106/106 [==============================] - 4s 36ms/step - loss: 5.1931e-04 - val_loss: 0.0016
# Epoch 11/50
# 106/106 [==============================] - 5s 51ms/step - loss: 4.6791e-04 - val_loss: 0.0014
# Epoch 12/50
# 106/106 [==============================] - 4s 35ms/step - loss: 4.9504e-04 - val_loss: 0.0013
# Epoch 13/50
# 106/106 [==============================] - 4s 35ms/step - loss: 6.4150e-04 - val_loss: 0.0036
# INFO:bitcoin_utils:Model training complete.
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Visualize Model Performance
#
# We plot the training and validation loss to observe how the model learns.

# %%
plot_training_loss(history)
# Out:
# INFO:bitcoin_utils:Plotting training and validation loss.

# %%
# Prepare last input
X_input = X[-1:].copy()
recent_prices = df['price'].iloc[-60:].values

# Predict and plot
predicted_price = predict_next_price(model, X_input, scaler_y, recent_prices, plot=True)
print(f"📈 Predicted Next Price: ${predicted_price:,.2f}")
# Out:
# INFO:bitcoin_utils:Predicting next Bitcoin price using latest sequence...
# 1/1 [==============================] - 0s 364ms/step
# INFO:bitcoin_utils:Plotting recent prices with prediction...
# INFO:bitcoin_utils:Predicted price: $90,417.96
# 📈 Predicted Next Price: $90,417.96
