# %%
# Cell 1: Imports
from bitcoin_utils import fetch_price, record_price, preprocess, plot_data
import time
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image, display

# %%
# Cell 2: Fetch and display current BTC price in USD
price = fetch_price()
print(f" Live Bitcoin Price (USD): ${price:.2f}")
# Out:
#  Live Bitcoin Price (USD): $103777.00

# %%
# Cell 3: Record the fetched price with timestamp into CSV
record_price()
print(" Recorded price to data/bitcoin_prices.csv")
# Out:
#  Recorded price to data/bitcoin_prices.csv

# %%
import pandas as pd
from datetime import datetime, timedelta, UTC

# Load data
df = pd.read_csv("data/bitcoin_prices.csv")

# Convert timestamps to UTC-aware datetime
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.tz_localize('UTC')

# Get current time and filter last 30 minutes
now = datetime.now(UTC)
start_time = now - timedelta(minutes=30)
df_30min = df[df['timestamp'] >= start_time].sort_values('timestamp')

# Format the timestamp nicely for display
df_30min['Day'] = df_30min['timestamp'].dt.strftime("%A")
df_30min['Date'] = df_30min['timestamp'].dt.strftime("%B %d, %Y")
df_30min['Time (UTC)'] = df_30min['timestamp'].dt.strftime("%I:%M %p")
df_30min['Price (USD)'] = df_30min['price'].map("${:,.2f}".format)

# Select and reorder columns for display
display_table = df_30min[['Day', 'Date', 'Time (UTC)', 'Price (USD)']]

# Display as a styled table
display(display_table.style.set_caption("📊 Bitcoin Prices in the Last 30 Minutes").set_table_styles([{
    'selector': 'caption',
    'props': [('font-size', '16px'), ('font-weight', 'bold')]
}]))
# Out:
# <style type="text/css">
# #T_fadfc caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# </style>
# <table id="T_fadfc">
#   <caption>📊 Bitcoin Prices in the Last 30 Minutes</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fadfc_level0_col0" class="col_heading level0 col0" >Day</th>
#       <th id="T_fadfc_level0_col1" class="col_heading level0 col1" >Date</th>
#       <th id="T_fadfc_level0_col2" class="col_heading level0 col2" >Time (UTC)</th>
#       <th id="T_fadfc_level0_col3" class="col_heading level0 col3" >Price (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fadfc_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_fadfc_row0_col0" class="data row0 col0" >Friday</td>
#       <td id="T_fadfc_row0_col1" class="data row0 col1" >May 16, 2025</td>
#       <td id="T_fadfc_row0_col2" class="data row0 col2" >06:55 PM</td>
# ...

# %%
# Cell 2: Record BTC prices every 10 seconds (12 times = 2 minutes)

print(" Recording live prices for 120 seconds...\n")
for i in range(12):  # 12 records x 10 seconds = 2 minutes
    record_price()
    print(f" Recorded price {i+1}/12")
    time.sleep(10)

print("\n Finished collecting data.")
# Out:
#  Recording live prices for 120 seconds...
#
#  Recorded price 1/12
#  Recorded price 2/12
#  Recorded price 3/12
#  Recorded price 4/12
#  Recorded price 5/12
#  Recorded price 6/12
#  Recorded price 7/12
#  Recorded price 8/12
#  Recorded price 9/12
# Error fetching price: 'bitcoin'
# Price not available.
#  Recorded price 10/12
# Error fetching price: 'bitcoin'
# Price not available.
#  Recorded price 11/12
# Error fetching price: 'bitcoin'
# Price not available.
#  Recorded price 12/12
#
#  Finished collecting data.

# %%
import pandas as pd
from datetime import datetime
from IPython.display import display

# Load all recorded data
df = pd.read_csv("data/bitcoin_prices.csv")

# Parse timestamps
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Get the last 12 entries only (1 per record attempt)
df_last12 = df.tail(12).copy()

# Format timestamp for better readability
df_last12['Day'] = df_last12['timestamp'].dt.strftime("%A")
df_last12['Date'] = df_last12['timestamp'].dt.strftime("%B %d, %Y")
df_last12['Time (UTC)'] = df_last12['timestamp'].dt.strftime("%I:%M:%S %p")

# Format price (and flag any failed fetch as NaN or missing)
df_last12['Bitcoin Price (USD)'] = df_last12['price'].apply(
    lambda p: "${:,.2f}".format(p) if pd.notnull(p) else "❌ Error"
)

# Final display table
display_table = df_last12[['Day', 'Date', 'Time (UTC)', 'Bitcoin Price (USD)']]

# Display it as a clean styled table
display(
    display_table.style.set_caption("📊 Last 12 Bitcoin Price Fetches (from 2-minute loop)").set_table_styles([{
        'selector': 'caption',
        'props': [('font-size', '16px'), ('font-weight', 'bold')]
    }])
)
# Out:
# <style type="text/css">
# #T_3cb9c caption {
#   font-size: 16px;
#   font-weight: bold;
# }
# </style>
# <table id="T_3cb9c">
#   <caption>📊 Last 12 Bitcoin Price Fetches (from 2-minute loop)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cb9c_level0_col0" class="col_heading level0 col0" >Day</th>
#       <th id="T_3cb9c_level0_col1" class="col_heading level0 col1" >Date</th>
#       <th id="T_3cb9c_level0_col2" class="col_heading level0 col2" >Time (UTC)</th>
#       <th id="T_3cb9c_level0_col3" class="col_heading level0 col3" >Bitcoin Price (USD)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cb9c_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_3cb9c_row0_col0" class="data row0 col0" >Friday</td>
#       <td id="T_3cb9c_row0_col1" class="data row0 col1" >May 16, 2025</td>
#       <td id="T_3cb9c_row0_col2" class="data row0 col2" >07:10:58 PM</td>
# ...

# %%
# Cell 3: Preprocess the CSV into enriched DataFrame
df = preprocess()
df.tail()
# Out:
#                     timestamp   price  price_diff  rolling_avg
# 33 2025-05-16 19:17:05.927305  103775         0.0     103777.4
# 34 2025-05-16 19:17:16.034370  103775         0.0     103776.2
# 35 2025-05-16 19:17:26.152478  103775         0.0     103775.0
# 36 2025-05-16 19:17:36.265806  103775         0.0     103775.0
# 37 2025-05-16 19:17:46.375374  103766        -9.0     103773.2

# %%
# Cell 4: Save main plot to PNG and display it
plot_data(df)
display(Image("Output/bitcoin_price_plot.png"))

# %%
# Cell 5: Plot price_diff and rolling_avg
df_clean = df.dropna(subset=['price_diff', 'rolling_avg'])

if not df_clean.empty:
    plt.figure(figsize=(10, 5))
    plt.plot(df_clean['timestamp'], df_clean['price_diff'], label='Price Change (Δ)', color='orange')
    plt.plot(df_clean['timestamp'], df_clean['rolling_avg'], label='Rolling Avg (5 pts)', color='green')
    plt.title("Bitcoin Price Δ and Rolling Avg (Last 120 Seconds)")
    plt.xlabel("Time")
    plt.ylabel("Price (USD)")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print(" Not enough data to plot price_diff and rolling_avg.")

# %%
# Cell 6: Summary of recorded prices
df[['price', 'price_diff', 'rolling_avg']].describe()
# Out:
#                price  price_diff    rolling_avg
# count      38.000000   37.000000      34.000000
# mean   103811.657895   -6.297297  103807.664706
# std        41.723852   19.900956      26.198530
# min    103766.000000 -108.000000  103773.200000
# 25%    103781.000000   -1.000000  103782.950000
# 50%    103803.000000    0.000000  103806.100000
# 75%    103828.000000    0.000000  103826.750000
# max    103999.000000   15.000000  103883.800000

# %%
# Bonus Cell 8: Flag volatility based on price_diff
volatility_threshold = 25  # you can tune this

df['volatile'] = df['price_diff'].abs() > volatility_threshold
vol_count = df['volatile'].sum()

print(f" Detected {vol_count} volatile price jumps (>{volatility_threshold} USD)")

# Display volatile points
df[df['volatile']].tail()
# Out:
#  Detected 2 volatile price jumps (>25 USD)
#                    timestamp   price  price_diff  rolling_avg  volatile
# 1 2025-05-16 18:55:07.655319  103891      -108.0          NaN      True
# 2 2025-05-16 18:58:26.520632  103843       -48.0          NaN      True

# %%
# Bonus Cell 9: Plot volatile price change spikes
df_vol = df[df['volatile']].dropna()

if not df_vol.empty:
    plt.figure(figsize=(10, 5))
    plt.stem(df_vol['timestamp'], df_vol['price_diff'], basefmt=" ", use_line_collection=True)
    plt.title("⚡ Detected Volatile Bitcoin Price Spikes")
    plt.xlabel("Time")
    plt.ylabel("Price Change (Δ USD)")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print(" No significant volatility detected in this session.")
# Out:
#  No significant volatility detected in this session.
