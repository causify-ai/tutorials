# %% [markdown]
# # PyCaret Time Series API for Bitcoin Forecasting
#
# This notebook demonstrates real-time Bitcoin price forecasting using:
# - Live data from CoinGecko API
# - PyCaret's time series module
# - Data pipeline building.
#
# **References**:
# - [CoinGecko API Docs](https://www.coingecko.com/en/api/documentation)
# - [PyCaret Time Series Docs](https://pycaret.gitbook.io/docs/get-started/modules)

# %%
#import os
#os.environ['LD_PRELOAD'] = '/lib/aarch64-linux-gnu/libgomp.so.1'  # For ARM systems
# OR for regular Linux:
#os.environ['LD_PRELOAD'] = '/usr/lib/x86_64-linux-gnu/libgomp.so.1'

# Must be set BEFORE importing pycaret/
#os.environ['LD_PRELOAD'] = '/usr/lib/aarch64-linux-gnu/libgomp.so.1'

#from pycaret.time_series import *

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# Imports
import logging
import requests
import numpy as np
import pandas as pd
import plotly.express as px
from pycaret.time_series import *
from datetime import datetime, timedelta

# Configuration
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
pd.set_option('display.max_columns', 50)

# %%
import pycaret
print(pycaret.__version__)
# Out:
# 3.3.2

# %%
class CoinGeckoAPI:
    """
    Professional API client for CoinGecko with error handling and rate limiting.
    """
    
    BASE_URL = "https://api.coingecko.com/api/v3"
    
    def __init__(self, api_key=None):
        self.session = requests.Session()
        self.api_key = api_key
        self.last_call = None
        self.RATE_LIMIT = 10  # calls per minute
        
    def get_ohlc(self, coin_id="bitcoin", vs_currency="usd", days="max"):
        """
        Get OHLC data with professional error handling.
        
        :param coin_id: Cryptocurrency ID (default: bitcoin)
        :param vs_currency: Target currency (default: usd)
        :param days: Data history length (default: max)
        :return: DataFrame with columns [timestamp, open, high, low, close]
        """
        endpoint = f"{self.BASE_URL}/coins/{coin_id}/ohlc"
        params = {
            "vs_currency": vs_currency,
            "days": days
        }
        
        try:
            response = self.session.get(endpoint, params=params)
            response.raise_for_status()
            data = response.json()
            
            df = pd.DataFrame(data, columns=['timestamp', 'open', 'high', 'low', 'close'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            df.set_index('timestamp', inplace=True)
            
            logger.info(f"Successfully fetched {len(df)} records")
            return df
            
        except Exception as e:
            logger.error(f"API Error: {str(e)}")
            raise

# Initialize client
cg = CoinGeckoAPI()

# %%
def fetch_and_validate_data(days=90):
    """
    End-to-end data pipeline with quality checks and feature engineering.
    
    Parameters:
    -----------
    days : int
        Number of days of historical data to fetch
        
    Returns:
    --------
    pd.DataFrame
        Processed data ready for analysis
    """
    # Fetch raw data
    raw_data = cg.get_ohlc(days=days)
    
    # Validation Checks
    assert isinstance(raw_data, pd.DataFrame), "Data must be a DataFrame"
    assert not raw_data.empty, "Empty data received"
    assert {'open', 'high', 'low', 'close'}.issubset(raw_data.columns), "Missing OHLC columns"
    
    # Data Cleaning
    data = raw_data.copy()
    data = data[~data.index.duplicated(keep='first')]
    
    # Feature Engineering
    data['daily_return'] = data['close'].pct_change()
    data['volatility_7d'] = data['daily_return'].rolling(7).std()
    data['volume_ema_14'] = data['close'].ewm(span=14).mean()
    
    logger.info(f"Data validation passed. Final shape: {data.shape}")
    return data

# Fetch and display data
btc_data = fetch_and_validate_data()
display(btc_data.tail(3))
# Out:
# INFO:__main__:Successfully fetched 23 records
# INFO:__main__:Data validation passed. Final shape: (23, 7)
#                open     high      low    close  daily_return  volatility_7d  \
# timestamp
# 2025-04-30  94739.0  95491.0  92953.0  94256.0     -0.005455       0.034763
# 2025-05-04  94275.0  97822.0  93334.0  95923.0      0.017686       0.031335
# 2025-05-08  95893.0  97512.0  93592.0  97026.0      0.011499       0.028500
#
#             volume_ema_14
# timestamp
# 2025-04-30   87978.831674
# 2025-05-04   89085.564536
# 2025-05-08   90185.200939

# %%
def setup_experiment(data):
    """
    Properly configured PyCaret time series experiment for financial data.
    
    Parameters:
    -----------
    data : pd.DataFrame
        Must have datetime index and numeric columns
        
    Returns:
    --------
    TSForecastingExperiment
    """
    try:
        # Ensure proper data formatting
        if not isinstance(data.index, pd.DatetimeIndex):
            raise ValueError("Data must have datetime index")
            
        # Convert to numeric and drop NA
        numeric_data = data.select_dtypes(include=np.number)
        numeric_data = numeric_data.dropna()
        
        
        # Initialize experiment
        exp = setup(
            data=numeric_data,
            target='close',
            #index=data.index,
            fold_strategy='expanding',
            fold=3,
            numeric_imputation_target='ffill',
            session_id=42,
            fh=7,
            verbose=True
        )
        logger.info("PyCaret experiment successfully initialized")
        return exp
        
    except Exception as e:
        logger.error(f"Setup failed: {str(e)}")
        raise

# Properly formatted data
btc_data_formatted = btc_data[['close']].copy()
btc_data_formatted = btc_data_formatted.asfreq('D').ffill()  # Ensure daily frequency

# Initialize experiment
exp = setup_experiment(btc_data_formatted)
# Out:
# <style type="text/css">
# #T_11c4d_row31_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_11c4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11c4d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_11c4d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11c4d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11c4d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_11c4d_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11c4d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_11c4d_row1_col1" class="data row1 col1" >close</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_11c4d_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_11c4d_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_11c4d_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_11c4d_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_11c4d_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_11c4d_row4_col1" class="data row4 col1" >(89, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_11c4d_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_11c4d_row5_col1" class="data row5 col1" >(89, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_11c4d_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_11c4d_row6_col1" class="data row6 col1" >(82, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_11c4d_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_11c4d_row7_col1" class="data row7 col1" >(7, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_11c4d_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_11c4d_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_11c4d_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_11c4d_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_11c4d_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_11c4d_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_11c4d_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_11c4d_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_11c4d_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_11c4d_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_11c4d_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_11c4d_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_11c4d_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_11c4d_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_11c4d_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_11c4d_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_11c4d_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_11c4d_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_11c4d_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_11c4d_row17_col1" class="data row17 col1" >[]</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_11c4d_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_11c4d_row18_col1" class="data row18 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_11c4d_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_11c4d_row19_col1" class="data row19 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_11c4d_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_11c4d_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_11c4d_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_11c4d_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_11c4d_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_11c4d_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_11c4d_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_11c4d_row23_col1" class="data row23 col1" >[1]</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_11c4d_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_11c4d_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_11c4d_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_11c4d_row25_col1" class="data row25 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_11c4d_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_11c4d_row26_col1" class="data row26 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_11c4d_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_11c4d_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_11c4d_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_11c4d_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_11c4d_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_11c4d_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_11c4d_level0_row30" class="row_heading level0 row30" >30</th>
#       <td
# INFO:__main__:PyCaret experiment successfully initialized
