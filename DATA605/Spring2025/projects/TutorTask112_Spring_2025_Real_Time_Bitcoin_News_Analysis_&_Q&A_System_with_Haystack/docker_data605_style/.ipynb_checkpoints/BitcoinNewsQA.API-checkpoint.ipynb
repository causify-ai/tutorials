# %%
# BitcoinNewsQA.API.ipynb

# Step 1: Import Utility Functions
from BitcoinNewsQA_utils import fetch_crypto_news, create_documents, split_documents

# Step 2: Fetch Raw News from CryptoPanic
news_data = fetch_crypto_news()
print(f"Fetched {len(news_data)} articles.")
news_data[0]
# Out:
# Fetched 20 articles.
# {'title': 'Dogwifhat (WIF) Targets $1.50 Amid 50% Weekly Jump – Here Are The Levels To Watch',
#  'content': 'https://cryptopanic.com/news/21870698/Dogwifhat-WIF-Targets-150-Amid-50-Weekly-Jump-Here-Are-The-Levels-To-Watch?mtm_campaign=API-OFA',
#  'published_at': '2025-05-17T05:30:24Z',
#  'source': 'newsbtc.com'}

# %%
# Step 3: Convert Articles to Haystack Documents
documents = create_documents(news_data)
print(f"Converted to {len(documents)} Haystack documents.")
documents[0].to_dict()
# Out:
# Converted to 20 Haystack documents.
# {'content': 'Dogwifhat (WIF) Targets $1.50 Amid 50% Weekly Jump – Here Are The Levels To Watch - https://cryptopanic.com/news/21870698/Dogwifhat-WIF-Targets-150-Amid-50-Weekly-Jump-Here-Are-The-Levels-To-Watch?mtm_campaign=API-OFA',
#  'content_type': 'text',
#  'score': None,
#  'meta': {'source': 'newsbtc.com'},
#  'id_hash_keys': ['content'],
#  'embedding': None,
#  'id': 'aca8bfee56d268cde38a3cc1c0be72b5'}

# %%
# Step 4: Preprocess Text into Chunks
chunks = split_documents(documents)
print(f"Generated {len(chunks)} document chunks.")
chunks[0].to_dict()
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/priyamchhonkar/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# Preprocessing: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 93.81docs/s]
# Generated 20 document chunks.
# {'content': 'Dogwifhat (WIF) Targets $1.50 Amid 50% Weekly Jump – Here Are The Levels To Watch - https://cryptopanic.com/news/21870698/Dogwifhat-WIF-Targets-150-Amid-50-Weekly-Jump-Here-Are-The-Levels-To-Watch?mtm_campaign=API-OFA',
#  'content_type': 'text',
#  'score': None,
#  'meta': {'source': 'newsbtc.com', '_split_id': 0, '_split_overlap': []},
#  'id_hash_keys': ['content'],
#  'embedding': None,
#  'id': 'aca8bfee56d268cde38a3cc1c0be72b5'}
