# %% [markdown]
# # SHAP API Notebook
#
# This is a template notebook. The first heading should be the title of what notebook is about. For example, if it is a neo4j tutorial the heading should be `Neo4j API`.
#
# - Add description of what the notebook does.
# - Point to references, e.g. (neo4j.API.md)
# - Add citations.
# - Keep the notebook flow clear.
# - Comments should be imperative and have a period at the end.
# - Your code should be well commented.
#
# The name of this notebook should in the following format:
# - if the notebook is exploring `pycaret API`, then it is `pycaret.API.ipynb`
#
# Follow the reference to write notebooks in a clear manner: https://github.com/causify-ai/helpers/blob/master/docs/coding/all.jupyter_notebook.how_to_guide.md

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Imports

# %%
import logging
import requests
import pandas as pd
import numpy as np
import sys
import os

# custom logic imports
from ingestion.fetch_data import load_config
from ingestion.dataset_builders import build_hourly_180d_dataset, build_daily_max_dataset

# %% [markdown]
# ## Configuration

# %%
# hdbg.init_logger(verbosity=logging.INFO)

# _LOG = logging.getLogger(__name__)

# hprint.config_notebook()

# %%
# Add the src directory to the Python path
sys.path.append("../src")

# %%
config = load_config("config/config.yaml")
df = fetch_market_chart_data(config)
save_market_data(df)
df.head()
# Out:
# Saved market data to data/btc_market_chart_20250419_173509.csv
#                 timestamp         price    market_cap        volume
# 0 2025-04-18 21:36:36.965  84559.106420  1.677944e+12  9.863965e+09
# 1 2025-04-18 21:41:55.307  84571.312657  1.679022e+12  9.903695e+09
# 2 2025-04-18 21:45:57.172  84613.601801  1.679541e+12  9.895311e+09
# 3 2025-04-18 21:51:06.884  84587.820525  1.679832e+12  9.865522e+09
# 4 2025-04-18 21:56:07.202  84575.721581  1.679099e+12  9.839719e+09

# %%
df.shape
# Out:
# (288, 4)
