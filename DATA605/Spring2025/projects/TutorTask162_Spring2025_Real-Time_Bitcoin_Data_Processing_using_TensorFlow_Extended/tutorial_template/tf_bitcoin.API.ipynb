# %% [markdown]
# # Bitcoin API
#
# This notebook demonstrates how to fetch real-time Bitcoin price data using the CoinGecko API.
#
# - Uses helper utilities from `bitcoin_utils.py`.
# - Demonstrates clean API interaction, visualization, and schema inspection.
# - Refer to `bitcoin.API.md` for extended documentation.
# - CoinGecko API: https://www.coingecko.com/en/api/documentation

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Imports

# %%
import logging
from tf_bitcoin_utils import fetch_bitcoin_prices, plot_bitcoin_prices

# %% [markdown]
# ## Configuration

# %%
# Configure logging
logging.basicConfig(level=logging.INFO)
_LOG = logging.getLogger(__name__)

# %% [markdown]
# ### Load Data

# %%
df = fetch_bitcoin_prices(days=7)
df.head()
# Out:
# INFO:root:Fetching data from https://api.coingecko.com/api/v3/coins/bitcoin/market_chart with params {'vs_currency': 'usd', 'days': 7}
#                 timestamp         price
# 0 2025-04-24 03:09:34.846  93177.558204
# 1 2025-04-24 04:06:27.582  92791.867385
# 2 2025-04-24 05:22:45.076  92830.136745
# 3 2025-04-24 06:24:09.724  92422.333610
# 4 2025-04-24 07:14:50.774  92481.314871

# %% [markdown]
# ### Save into CSV

# %%
import os
os.makedirs("data/bitcoin", exist_ok=True)
df.to_csv("data/bitcoin/bitcoin_prices.csv", index=False)

# %% [markdown]
# ## Visualize Bitcoin Price

# %%
plot_bitcoin_prices(df)
# Out:
# INFO:tf_bitcoin_utils:Plotting Bitcoin price data...
