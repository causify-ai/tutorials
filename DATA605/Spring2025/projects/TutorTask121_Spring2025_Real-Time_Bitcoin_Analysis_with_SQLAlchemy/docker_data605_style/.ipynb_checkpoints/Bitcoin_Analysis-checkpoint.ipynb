# %% [markdown]
# ## Data Pre-Processing

# %%
import pandas as pd
from sqlalchemy import create_engine

# Step 1: Connect to DB and load into DataFrame
engine = create_engine("sqlite:///bitcoin_data.db")
df = pd.read_sql("SELECT * FROM bitcoin_prices", con=engine)

# Step 2: Preprocessing
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index('timestamp', inplace=True)
df = df.sort_index()

# Step 3: Drop duplicates
df = df[~df.index.duplicated()]

# Step 4: Check for missing values
print("Missing values:\n", df.isnull().sum())
print("\nData coverage:\n", df.index.min(), "→", df.index.max())
print(df.describe())
# Out:
# Missing values:
#  id       0
# price    0
# dtype: int64
#
# Data coverage:
#  2025-03-26 00:00:00 → 2025-05-17 04:38:39.983514
#              id          price
# count  800.0000     800.000000
# mean   400.5000   96324.246290
# std    231.0844    6239.727102
# min      1.0000   83998.876506
# 25%    200.7500   93761.948206
# 50%    400.5000   95496.893520
# 75%    600.2500  103212.537732
# max    800.0000  104778.262185

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))
plt.plot(df.index, df['price'], label='BTC Price', linewidth=2)
plt.title(" Bitcoin Price Over Time", fontsize=14)
plt.xlabel("Time", fontsize=12)
plt.ylabel("Price (USD)", fontsize=12)
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 4))
plt.hist(df['price'], bins=30, color='steelblue', edgecolor='black')
plt.axvline(df['price'].mean(), color='red', linestyle='--', label=f"Mean: ${df['price'].mean():,.0f}")
plt.axvline(df['price'].median(), color='green', linestyle='--', label=f"Median: ${df['price'].median():,.0f}")
plt.title(" Distribution of Bitcoin Prices", fontsize=14)
plt.xlabel("Price (USD)", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
plt.legend()
plt.tight_layout()
plt.show()

# %%
df['rolling_avg_7'] = df['price'].rolling(window=7).mean()
df['rolling_std_7'] = df['price'].rolling(window=7).std()

plt.figure(figsize=(12, 5))
plt.plot(df.index, df['price'], label='Price', alpha=0.6)
plt.plot(df.index, df['rolling_avg_7'], label='7-period MA', linestyle='--', color='darkblue')
plt.fill_between(df.index,
                 df['rolling_avg_7'] - df['rolling_std_7'],
                 df['rolling_avg_7'] + df['rolling_std_7'],
                 color='orange', alpha=0.3, label='Volatility Band')
plt.title("📉 BTC Price with Rolling Average and Volatility", fontsize=14)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128201 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df['returns'] = df['price'].pct_change()

# %%
plt.figure(figsize=(12, 4))
df['returns'].plot(color='purple', linewidth=1)
plt.axhline(0, color='black', linestyle='--', alpha=0.7)

# Annotate max and min return
max_r = df['returns'].max()
min_r = df['returns'].min()
plt.scatter(df['returns'].idxmax(), max_r, color='green')
plt.scatter(df['returns'].idxmin(), min_r, color='red')
plt.annotate(f"Max: {max_r:.2%}", xy=(df['returns'].idxmax(), max_r), xytext=(10, 10),
             textcoords='offset points', arrowprops=dict(arrowstyle="->", color='green'))
plt.annotate(f"Min: {min_r:.2%}", xy=(df['returns'].idxmin(), min_r), xytext=(10, -20),
             textcoords='offset points', arrowprops=dict(arrowstyle="->", color='red'))

plt.title(" Bitcoin Daily Returns", fontsize=14)
plt.ylabel("Daily % Change")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Bitcoin Price Pattern (Mar 26 – May 17):
# Bitcoin slowly increased from ~$84K to over $104K with visible short-term corrections. Mid-April and early May show high volatility, possibly due to outside news or economic events.
#
# Price Distribution:
# The histogram shows three dominant price levels: ~$88K, ~$95K, and ~$103K, reflecting market action in phases — possibly accumulation, breakout, and resistance testing.
#
# Volatility Band:
# Periods of high volatility expansion (wide bands) coincide with increasing price tendencies, upholding that spikes in prices are generally encompassing spikes in risk — an important instrument for short-term investors.
#
# Returns Behavior:
# Returns fluctuate around 0 by having several spikes in returns, perhaps indicative of trading opportunity. They are predominantly steady, upholding BTC as a mature market.

# %% [markdown]
# ## Feature Enginneering

# %%
# Returns already created before:
df['returns'] = df['price'].pct_change()

# Rolling statistics (trend & volatility)
df['rolling_avg_7'] = df['price'].rolling(window=7).mean()
df['rolling_std_7'] = df['price'].rolling(window=7).std()

# Lag features — past prices
df['lag_1'] = df['price'].shift(1)
df['lag_2'] = df['price'].shift(2)

# Temporal Features
df['hour'] = df.index.hour      # if intraday
df['day_of_week'] = df.index.dayofweek  # Monday=0

# Drop rows with any NaN (caused by rolling or lagging)
df.dropna(inplace=True)

# Preview
df.head()
# Out:
#                          id         price  rolling_avg_7  rolling_std_7  \
# timestamp
# 2025-04-17 06:03:39.373  17  84424.607579   85497.301918    1639.680429
# 2025-04-17 07:04:57.904  18  84780.570982   85105.871499    1383.161851
# 2025-04-17 08:04:40.116  19  84657.330047   84776.796427    1116.617737
# 2025-04-17 09:00:54.998  20  84470.839300   84383.020387     284.128879
# 2025-04-17 10:03:03.153  21  84444.831138   84413.145681     276.773791
#
#                           returns         lag_1         lag_2  hour  \
# timestamp
# 2025-04-17 06:03:39.373  0.003681  84114.964214  83998.876506     6
# 2025-04-17 07:04:57.904  0.004216  84424.607579  84114.964214     7
# 2025-04-17 08:04:40.116 -0.001454  84780.570982  84424.607579     8
# 2025-04-17 09:00:54.998 -0.002203  84657.330047  84780.570982     9
# 2025-04-17 10:03:03.153 -0.000308  84470.839300  84657.330047    10
#
#                          day_of_week
# timestamp
# 2025-04-17 06:03:39.373            3
# ...

# %% [markdown]
# We engineered several domain-specific features using Bitcoin price time-series. These include returns (momentum), lagged prices (persistence), rolling average (trend), volatility (risk), and time-based variables (seasonality). This feature set provides a strong feature set for predictive modeling.

# %% [markdown]
# ## Model Training

# %%
df['target'] = df['price'].shift(-1) 
df.dropna(inplace=True)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Feature columns
feature_cols = ['price', 'lag_1', 'lag_2', 'returns', 
                'rolling_avg_7', 'rolling_std_7', 'hour', 'day_of_week']

X = df[feature_cols]
y = df['target']

# Create polynomial and interaction terms (degree=2)
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

# Chronological train-test split
split_index = int(len(X_poly) * 0.8)
X_train, X_test = X_poly[:split_index], X_poly[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

# Fit model
lr_poly = LinearRegression()
lr_poly.fit(X_train, y_train)

# Predict
y_pred_poly = lr_poly.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred_poly)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_poly))
r2 = r2_score(y_test, y_pred_poly)

print(f" Polynomial Linear Regression:\nMAE: ${mae:.2f}\nRMSE: ${rmse:.2f}\nR²: {r2:.4f}")
# Out:
#  Polynomial Linear Regression:
# MAE: $163.43
# RMSE: $262.15
# R²: 0.7024

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
plt.plot(y_test.values, label='📈 Actual BTC Price', color='black', linewidth=2)
plt.plot(y_pred, label=' Predicted BTC Price', linestyle='--', color='orange', linewidth=2)

plt.title("🔍 Bitcoin Price Forecast: Actual vs Predicted", fontsize=16)
plt.xlabel("Time Step (Test Set)", fontsize=12)
plt.ylabel("Price (USD)", fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128200 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# We also trained Linear Regression model to forecast the next time-step Bitcoin price using lagged values, rolling statistics, and time features. The model worked with MAE of $191.88 and RMSE of $289.11 and decent predictive ability. The actual vs. predicted plot shows that the model can follow the overall trend well but has a bit of trouble during the episodes of high volatility.

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_pred)
print(f" R² Score: {r2:.4f}")
# Out:
#  R² Score: 0.7394

# %%
residuals = y_test.values - y_pred

plt.figure(figsize=(12, 5))
plt.plot(residuals, marker='o', linestyle='-', color='darkred')
plt.axhline(0, color='black', linestyle='--')
plt.title("📉 Residual Plot: Prediction Errors (Actual - Predicted)")
plt.xlabel("Time Step (Test Set)")
plt.ylabel("Residual (USD)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128201 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np

plt.figure(figsize=(14, 6))

# Base actual values
plt.plot(y_test.values, label=' Actual BTC Price', color='black', linewidth=2)

# Color-coded scatter
errors = y_pred - y_test.values
colors = np.where(errors > 0, 'red', 'green')
plt.scatter(range(len(y_pred)), y_pred, c=colors, label=' Predicted Price', alpha=0.7)

plt.title(" Actual vs Predicted BTC Price (Color-Coded Residuals)", fontsize=16)
plt.xlabel("Time Step (Test Set)", fontsize=12)
plt.ylabel("Price (USD)", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae_rf = mean_absolute_error(y_test, y_rf_pred)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_rf_pred))  # Manually take sqrt for RMSE
r2_rf = r2_score(y_test, y_rf_pred)

print(f" Random Forest Results:\nMAE: ${mae_rf:.2f}\nRMSE: ${rmse_rf:.2f}\nR²: {r2_rf:.4f}")
# Out:
#  Random Forest Results:
# MAE: $235.06
# RMSE: $327.36
# R²: 0.5359

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
plt.plot(y_test.values, label=' Actual', color='black')
plt.plot(y_rf_pred, label=' Predicted (Random Forest)', linestyle='--', color='forestgreen')
plt.title(" BTC Forecast: Actual vs Random Forest", fontsize=16)
plt.xticks(ticks=np.arange(0, len(y_test), step=20))
plt.xlabel("Time Step (Test Set)", fontsize=12)
plt.ylabel("Price (USD)", fontsize=12)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import matplotlib.pyplot as plt

# Rebuild poly with the same degree
poly = PolynomialFeatures(degree=2, include_bias=False)
poly.fit(X)

# Use correct feature name extractor for sklearn >= 1.0
feature_names_poly = poly.get_feature_names_out(input_features=X.columns)

# Get importances from trained Random Forest on X_poly
importances = rf.feature_importances_

# Plot sorted feature importances
sorted_idx = importances.argsort()

plt.figure(figsize=(10, 6))
plt.barh(np.array(feature_names_poly)[sorted_idx], importances[sorted_idx], color='slateblue')
plt.title("🌲 Feature Importance - Random Forest (Polynomial Features)", fontsize=14)
plt.xlabel("Importance Score")
plt.tight_layout()
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 127794 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 127794 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# The Random Forest model was trained to predict the next-hour Bitcoin price using historical, trend, and volatility-based features. It achieved an R² score of 0.59, indicating moderate explanatory power. The model favored lagged price values and rolling averages, which aligned with the nature of Bitcoin’s trend-following behavior. However, it struggled to adapt to sudden volatility shifts, as seen in the actual vs. predicted plots.

# %% [markdown]
# ## Comparison

# %%
plt.figure(figsize=(14, 6))

plt.plot(y_test.values, label=' Actual', color='black', linewidth=2)
plt.plot(y_pred, label='Linear Regression', linestyle='--', color='dodgerblue', linewidth=2)
plt.plot(y_rf_pred, label=' Random Forest', linestyle='--', color='green', linewidth=2)

plt.title("🔍 BTC Price Prediction: Linear vs Random Forest", fontsize=16)
plt.xlabel("Time Step (Test Set)", fontsize=12)
plt.ylabel("Price (USD)", fontsize=12)
plt.legend(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128269 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import seaborn as sns
import pandas as pd

# Residuals
residuals_lr = y_test.values - y_pred
residuals_rf = y_test.values - y_rf_pred

# Combine into DataFrame
res_df = pd.DataFrame({
    'Linear Regression': residuals_lr,
    'Random Forest': residuals_rf
})

# Boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(data=res_df, palette=['dodgerblue', 'forestgreen'])
plt.title(" Residuals Comparison: Linear vs RF", fontsize=14)
plt.ylabel("Prediction Error (USD)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Refine Linear Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# Select original features
feature_cols = ['price', 'lag_1', 'lag_2', 'returns', 
                'rolling_avg_7', 'rolling_std_7', 'hour', 'day_of_week']

X = df[feature_cols]
y = df['target']

# Generate interaction + squared terms (no bias, since LR adds it separately)
poly = PolynomialFeatures(degree=2, include_bias=False, interaction_only=False)
X_poly = poly.fit_transform(X)

# Feature names 
feature_names_poly = poly.get_feature_names_out(input_features=feature_cols)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred_poly)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_poly))  # Manual RMSE
r2 = r2_score(y_test, y_pred_poly)

print(f" Polynomial Linear Regression:\nMAE: ${mae:.2f}\nRMSE: ${rmse:.2f}\nR²: {r2:.4f}")
# Out:
#  Polynomial Linear Regression:
# MAE: $163.43
# RMSE: $262.15
# R²: 0.7024

# %%
plt.figure(figsize=(14, 6))
plt.plot(y_test.values, label='📈 Actual', color='black', linewidth=2)
plt.plot(y_pred_poly, label=' Polynomial LR', linestyle='--', color='indigo', linewidth=2)

plt.title(" BTC Price Forecast: Polynomial Linear Regression", fontsize=16)
plt.xlabel("Time Step (Test Set)")
plt.ylabel("Price (USD)")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128200 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.figure(figsize=(14, 6))
plt.plot(y_test.values, label='📈 Actual', color='black', linewidth=2)
plt.plot(y_pred, label='Linear', linestyle='--', color='dodgerblue')
plt.plot(y_pred_poly, label='Poly (deg=2)', linestyle='--', color='indigo')
plt.title(" Linear vs Polynomial Regression", fontsize=15)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128269 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128269 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/apple/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128200 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Assuming y_pred is from your simple LR model
mae_lr = mean_absolute_error(y_test, y_pred)
rmse_lr = np.sqrt(mean_squared_error(y_test, y_pred))
r2_lr = r2_score(y_test, y_pred)

# %%
print(" Final Model: Simple Linear Regression")
print(f"• MAE  : ${mae_lr:.2f}")
print(f"• RMSE : ${rmse_lr:.2f}")
print(f"• R²    : {r2_lr:.4f}")
# Out:
#  Final Model: Simple Linear Regression
# • MAE  : $158.65
# • RMSE : $245.29
# • R²    : 0.7394

# %% [markdown]
# The model explains ~74% of the variance in price while remaining transparent and fast to run. It’s a reliable choice for monitoring Bitcoin short-term trends.
