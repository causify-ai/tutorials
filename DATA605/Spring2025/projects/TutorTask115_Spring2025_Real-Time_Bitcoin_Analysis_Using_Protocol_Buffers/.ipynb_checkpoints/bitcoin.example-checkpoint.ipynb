# %% [markdown]
# # 📊 Bitcoin Market Analysis (Merged Historical + Real-Time)
# This notebook combines **historical hourly** and **real-time streamed** Bitcoin data to perform a holistic analysis. We aim to uncover patterns, anomalies, and price behavior useful for:
# - 📈 Trend detection (daily, hourly, minutely)
# - 📉 Volatility and anomaly spotting
# - 🤔 Buy/sell signal exploration

# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), 'src'))

from bitcoin_utils import load_protobuf_file, protobufs_to_dataframe
import matplotlib.pyplot as plt
import pandas as pd
import datetime

# %% [markdown]
# ## 🔄 Load and Combine Historical + Real-Time Data

# %%
hist_msgs = load_protobuf_file("src/data/bitcoin_historical_hourly.pb")
hist_df = protobufs_to_dataframe(hist_msgs)

real_path = datetime.datetime.now().strftime("src/data/bitcoin_data_%Y-%m-%d.pb")
real_msgs = load_protobuf_file(real_path)
real_df = protobufs_to_dataframe(real_msgs)

full_df = pd.concat([hist_df, real_df], ignore_index=True)
full_df = full_df.drop_duplicates(subset="timestamp").sort_values("timestamp")
print(f"📦 Combined records: {len(full_df)}")
full_df.tail()
# Out:
# 📦 Combined records: 754
#               timestamp    price        volume    market_cap     source
# 749 2025-05-01 17:55:29  96655.0  3.063710e+10  1.919780e+12  CoinGecko
# 750 2025-05-01 17:55:59  96655.0  3.063710e+10  1.919780e+12  CoinGecko
# 751 2025-05-01 17:56:29  96655.0  3.063710e+10  1.919780e+12  CoinGecko
# 752 2025-05-01 17:56:59  96644.0  3.023194e+10  1.919294e+12  CoinGecko
# 753 2025-05-01 17:57:29  96644.0  3.023194e+10  1.919294e+12  CoinGecko

# %% [markdown]
# ## ⏱️ Bitcoin Price - Last 24 Hours

# %%
last_24h = full_df.set_index("timestamp").last("24H")
last_24h["price"].plot(figsize=(12, 4), title="Bitcoin Price (Last 24 Hours)")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
# Out:
# /var/folders/yw/7nv526h96y59_0vhdnlch9k80000gn/T/ipykernel_44631/1714916832.py:1: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_24h = full_df.set_index("timestamp").last("24H")
# /var/folders/yw/7nv526h96y59_0vhdnlch9k80000gn/T/ipykernel_44631/1714916832.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   last_24h = full_df.set_index("timestamp").last("24H")

# %% [markdown]
# ## 🕒 Bitcoin Price - Last 3 Hours

# %%
last_3h = full_df.set_index("timestamp").last("3H")
last_3h["price"].plot(figsize=(12, 4), title="Bitcoin Price (Last 3 Hours)")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
# Out:
# /var/folders/yw/7nv526h96y59_0vhdnlch9k80000gn/T/ipykernel_44631/2440353927.py:1: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_3h = full_df.set_index("timestamp").last("3H")
# /var/folders/yw/7nv526h96y59_0vhdnlch9k80000gn/T/ipykernel_44631/2440353927.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   last_3h = full_df.set_index("timestamp").last("3H")

# %% [markdown]
# ## 📆 Daily Price Summary - Last 30 Days

# %%
full_df['date'] = full_df['timestamp'].dt.date
daily_summary = full_df.groupby('date')["price"].agg(["min", "max", "mean"])
daily_summary.plot(figsize=(12, 5), title="Daily Bitcoin Price Stats")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## ⚠️ High Volatility Hours (Anomaly Candidates)

# %%
hourly = full_df.copy()
hourly['hour'] = hourly['timestamp'].dt.floor('H')
volatility = hourly.groupby('hour')['price'].agg(['min', 'max'])
volatility['range'] = volatility['max'] - volatility['min']
anomalies = volatility[volatility['range'] > volatility['range'].mean() + 2*volatility['range'].std()]
anomalies.tail(10)
# Out:
# /var/folders/yw/7nv526h96y59_0vhdnlch9k80000gn/T/ipykernel_44631/2328587869.py:2: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   hourly['hour'] = hourly['timestamp'].dt.floor('H')
#                               min           max       range
# hour
# 2025-04-10 04:00:00  81618.620709  81696.401228   77.780519
# 2025-05-01 17:00:00  96468.249297  96724.000000  255.750703

# %% [markdown]
# ## 💡 Recent 15 Minute Stats (For Trade Insight)

# %%
last_15min = full_df.set_index("timestamp").last("15min")
summary = last_15min["price"].agg(["min", "max", "mean"])
summary
# Out:
# /var/folders/yw/7nv526h96y59_0vhdnlch9k80000gn/T/ipykernel_44631/3362282720.py:1: FutureWarning: last is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   last_15min = full_df.set_index("timestamp").last("15min")
# min     96644.000000
# max     96724.000000
# mean    96675.433333
# Name: price, dtype: float64
