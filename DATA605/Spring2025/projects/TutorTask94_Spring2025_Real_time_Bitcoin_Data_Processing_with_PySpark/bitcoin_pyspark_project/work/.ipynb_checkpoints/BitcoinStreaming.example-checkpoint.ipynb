# %% [markdown]
# # Bitcoin Forecasting Pipeline Example
# This notebook shows the full pipeline using `bitcoin_utils.py` to forecast Bitcoin prices.

# %% [markdown]
# # 1. Initialize Spark

# %%
from bitcoin_utils import initialize_spark_session
spark = initialize_spark_session()
# Out:
# 25/05/17 11:40:45 WARN Utils: Your hostname, rajesh resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 25/05/17 11:40:45 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/17 11:40:46 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## 2 Load and Preview Historical Data

# %%
from bitcoin_utils import preview_historical_data

preview_historical_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 from bitcoin_utils import preview_historical_data
# ----> 3 preview_historical_data()
#
# File ~/bitcoin_pyspark_project/work/bitcoin_utils.py:145, in preview_historical_data()
#     143 def preview_historical_data():
#     144     df = spark.read.schema(schema).json("Data/bitcoin_combined.json")
# --> 145     df.show(5)
#     146     df.count()
#
# NameError: name 'spark' is not defined

# %%
from bitcoin_utils import configure_streaming_paths_and_schedule
configure_streaming_paths_and_schedule()

# %%
from bitcoin_utils import count_historical_records
count_historical_records()
# Out:
# Total records: 9170

# %%
from bitcoin_utils import fetch_price_as_ohlc
fetch_price_as_ohlc()
# Out:
# {'Datetime': '2025-05-17T15:47:45.873174+00:00',
#  'Open': 103111,
#  'High': 104263,
#  'Low': 102771,
#  'Close': 103111,
#  'Volume': '20607852462'}

# %%
from bitcoin_utils import start_file_producer
start_file_producer()
# Out:
# 📁 Wrote: Data/stream/ohlc_20250517_114908.json
# 📁 Wrote: Data/stream/ohlc_20250517_114938.json
# 📁 Wrote: Data/stream/ohlc_20250517_115009.json

# %%
from bitcoin_utils import stream_and_display_batches
stream_and_display_batches()
# Out:
# 25/05/17 11:50:42 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
from bitcoin_utils import count_historical_records
count_historical_records()
# Out:
# Total records: 9170

# %% [markdown]
# ## 2. Perform Aggregation and Moving Averages

# %%
from bitcoin_utils import aggregate_hourly_daily_moving_average

aggregate_hourly_daily_moving_average()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/14 21:45:00 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/05/14 21:45:01 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 🔹 Hourly Aggregation:
# +----+-----------------+----------------+----------------+
# |Hour|Hourly_Avg_Close |Hourly_Min_Close|Hourly_Max_Close|
# +----+-----------------+----------------+----------------+
# |0   |79952.38841081374|53912.7265625   |106101.5390625  |
# |1   |82385.9501865932 |53778.83984375  |106380.2578125  |
# |2   |80814.21034875898|53776.8828125   |106242.25       |
# |3   |77437.26053082192|53807.8203125   |106841.9296875  |
# |4   |77432.06124785959|53615.59375     |106508.46875    |
# |5   |77444.40470890411|52753.21484375  |106778.234375   |
# |6   |77428.57278467466|51460.3671875   |107157.2109375  |
# |7   |77431.2698630137 |52740.9140625   |107023.7890625  |
# |8   |77442.64475599315|52760.20703125  |108181.09375    |
# |9   |77480.6962114726 |52449.5546875   |108018.796875   |
# |10  |77478.00141267123|51367.140625    |107810.40625    |
# |11  |77492.22636986301|51435.578125    |108097.4375     |
# |2024-05-01 02:30:00|2024-05-01 03:30:00|60180.30859375  |
# |2024-05-01 03:00:00|2024-05-01 04:00:00|60180.30859375  |
# |2024-05-01 03:30:00|2024-05-01 04:30:00|60200.47265625  |
# |2024-05-01 04:00:00|2024-05-01 05:00:00|60200.47265625  |
# |2024-05-01 04:30:00|2024-05-01 05:30:00|59940.43359375  |
# |2024-05-01 05:00:00|2024-05-01 06:00:00|59940.43359375  |
# |2024-05-01 05:30:00|2024-05-01 06:30:00|59568.12890625  |
# |2024-05-01 06:00:00|2024-05-01 07:00:00|59568.12890625  |
# |2024-05-01 06:30:00|2024-05-01 07:30:00|57405.6328125   |
# |2024-05-01 07:00:00|2024-05-01 08:00:00|57405.6328125   |
# |2024-05-01 07:30:00|2024-05-01 08:30:00|57030.30078125  |
# |2024-05-01 08:00:00|2024-05-01 09:00:00|57030.30078125  |
# |2024-05-01 08:30:00|2024-05-01 09:30:00|57111.60546875  |
# |2024-05-01 09:00:00|2024-05-01 10:00:00|57111.60546875  |
# +-------------------+-------------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ## 3. Train GBT Model and Evaluate

# %%
from bitcoin_utils import train_and_evaluate_gbt_regressor

train_and_evaluate_gbt_regressor()
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.util.SizeEstimator$ (file:/opt/conda/lib/python3.11/site-packages/pyspark/jars/spark-core_2.12-3.4.1.jar) to field java.nio.charset.Charset.name
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.util.SizeEstimator$
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 25/05/14 21:45:56 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# +-----------------+--------------+------------------+
# |timestamp_numeric|Close         |prediction        |
# +-----------------+--------------+------------------+
# |1714528800       |59856.140625  |60494.46955650205 |
# |1714543200       |59568.12890625|60478.9362107707  |
# |1714550400       |57030.30078125|59932.448028253566|
# |1714568400       |57254.25390625|60299.65203063114 |
# |1714590000       |56858.4375    |60346.64278555952 |
# |1714604400       |58288.07421875|60772.24885450056 |
# |1714626000       |57440.5078125 |60328.85557170907 |
# |1714647600       |58557.0078125 |60245.1202487317  |
# |1714683600       |59121.5078125 |60498.51000012507 |
# |1714687200       |59328.3125    |61098.42789188326 |
# +-----------------+--------------+------------------+
# only showing top 10 rows
#
# ✅ GBT R²: 0.9682 (96.82%) variance explained
# ✅ GBT RMSE: 2863.92

# %% [markdown]
# ## 4. Visualize Results

# %%
from bitcoin_utils import plot_actual_vs_predicted_prices

plot_actual_vs_predicted_prices()
# Out:
# 🔍 Fetching predictions and converting datetime safely...
#              Datetime         Close    prediction
# 0 2024-05-01 02:00:00  59856.140625  60494.469557
# 1 2024-05-01 06:00:00  59568.128906  60478.936211
# 2 2024-05-01 08:00:00  57030.300781  59932.448028
# 3 2024-05-01 13:00:00  57254.253906  60299.652031
# 4 2024-05-01 19:00:00  56858.437500  60346.642786
