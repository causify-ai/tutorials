# %% [markdown]
# # Bitcoin API
#
# This notebook demonstrates how to interact with the CoinGecko Bitcoin price API using the utility functions defined in `bitcoin_utils.py`.
#
# ### Notebook Flow
#
# This notebook follows a clear and reproducible data processing flow:
#
# 1. Fetch real-time Bitcoin price from the CoinGecko API.
# 2. Save the price to a local CSV file.
# 3. Compute a moving average of recent Bitcoin prices.
# 4. Upload the processed file to S3 (optional).
#
#
# ### References:
#
# -  API Documentation: [bitcoin.API.md](bitcoin.API.md)
# -  CoinGecko API: [https://www.coingecko.com/en/api](https://www.coingecko.com/en/api)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Imports

# %%
import os
import logging
import importlib

# Set paths for local testing
os.makedirs("./data", exist_ok=True)
os.environ["BITCOIN_RAW_PATH"] = "./data/bitcoin_raw.csv"
os.environ["BITCOIN_PROCESSED_PATH"] = "./data/bitcoin_processed.csv"

# Reload the module to pick up new paths
import bitcoin_utils
importlib.reload(bitcoin_utils)

# %% [markdown]
# ### Configuration

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Fetch Bitcoin Price

# %%
btc_price = bitcoin_utils.fetch_bitcoin_price()
btc_price
# Out:
# INFO:bitcoin_utils:Fetched Bitcoin price successfully.
# {'timestamp': '2025-05-08T03:31:41.346373', 'price_usd': 98713}

# %% [markdown]
# ### Save Price to CSV

# %%
bitcoin_utils.save_price_to_csv()
# Out:
# INFO:bitcoin_utils:Fetched Bitcoin price successfully.
# INFO:bitcoin_utils:Saved price to ./data/bitcoin_raw.csv

# %% [markdown]
# ### Compute Moving Average

# %%
bitcoin_utils.compute_moving_average(window=2)
# Out:
# INFO:bitcoin_utils:Processed data saved to ./data/bitcoin_processed.csv

# %% [markdown]
# ### Upload Processed File to S3

# %%
bitcoin_utils.upload_to_s3("bitcoin-price-store", "processed/bitcoin_processed.csv")
# Out:
# INFO:bitcoin_utils:Uploading to S3...
# INFO:bitcoin_utils: Uploaded to s3://bitcoin-price-store/processed/bitcoin_processed.csv
