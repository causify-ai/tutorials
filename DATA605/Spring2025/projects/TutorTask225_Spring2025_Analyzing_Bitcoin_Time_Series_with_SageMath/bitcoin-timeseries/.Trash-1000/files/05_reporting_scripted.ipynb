# %% [markdown]
# # Bitcoin Time Series Forecasting Report
#
# This report summarizes forecasting results using symbolic regression, ARIMA, and SARIMA models on Bitcoin price data.

# %% [markdown]
# ## Full Time Series Plot

# %%
from IPython.display import Image
Image(filename='full_timeseries.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from IPython.display import Image
# ----> 2 Image(filename='full_timeseries.png')
#
# File ~/sage/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/IPython/core/display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File ~/sage/local/var/lib/sage/venv-python3.12.5/lib/python3.12/site-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
# ...

# %% [markdown]
# ## Rolling Averages and Volatility

# %%
Image(filename='rolling_averages.png')

# %%
Image(filename='volatility_rolling_stddev.png')

# %% [markdown]
# ## Zoomed-In Recent Data

# %%
Image(filename='zoomed_recent_60_30_days.png')

# %% [markdown]
# ## Symbolic Regression Results

# %%
Image(filename='symbolic_forecast_polydeg5.png')

# %%
Image(filename='symbolic_polynomial_fit_stable.png')

# %%
Image(filename='symbolic_polynomial_fit_deg7_7D.png')

# %%
Image(filename='symbolic_polynomial_fit.png')

# %%
import pandas as pd
symbolic_df = pd.read_csv('symbolic_forecast.csv')
symbolic_df.head()

# %%
with open('symbolic_metrics.txt') as f:
    print(f.read())

# %% [markdown]
# ## ARIMA Forecast

# %%
Image(filename='arima_forecast.png')

# %% [markdown]
# ## SARIMA & Comparison

# %%
Image(filename='arima_sarima_residuals.png')

# %%
Image(filename='arima_vs_sarima_comparison.png')

# %%
sarima_df = pd.read_csv('arima_vs_sarima_forecast.csv')
sarima_df.head()

# %% [markdown]
# ## Final Combined Plot

# %%
Image(filename='final_plot.png')
