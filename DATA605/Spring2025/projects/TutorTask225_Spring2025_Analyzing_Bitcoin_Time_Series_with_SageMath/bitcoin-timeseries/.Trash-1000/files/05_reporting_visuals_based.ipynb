# %% [markdown]
# # Bitcoin Time Series Forecasting Report
#
# ## 1. Overview
#
# This report summarizes forecasting results using symbolic regression, ARIMA, and SARIMA models on Bitcoin price data.
#
# ---
#
# ## 2. Full Time Series
#
# ![Full Time Series](full_timeseries.png)
#
# The complete price timeline shows distinct patterns of volatility and trends, important for model training and evaluation.
#
# ---
#
# ## 3. Exploratory Analysis
#
# **Rolling Averages and Volatility:**
#
# - ![Rolling Averages](rolling_averages.png)
# - ![Rolling StdDev](volatility_rolling_stddev.png)
#
# **Zoomed-In Recent Data:**
#
# - ![Zoomed Recent Data](zoomed_recent_60_30_days.png)
#
# ---
#
# ## 4. Symbolic Regression Results
#
# **Forecast Output:**
#
# - ![Symbolic Forecast](symbolic_forecast_polydeg5.png)
#
# **Polynomial Fits:**
#
# - ![Stable Polynomial Fit](symbolic_polynomial_fit_stable.png)
# - ![Polynomial Fit (deg7)](symbolic_polynomial_fit_deg7_7D.png)
# - ![Original Polynomial Fit](symbolic_polynomial_fit.png)
#
# **CSV + Metrics:**
#
# - `symbolic_forecast.csv`
# - `symbolic_metrics.txt`
#
# ---
#
# ## 5. ARIMA Model Results
#
# - ![ARIMA Forecast](arima_forecast.png)
#
# ---
#
# ## 6. SARIMA Model Results
#
# **Residuals:**
#
# - ![SARIMA Residuals](arima_sarima_residuals.png)
#
# **Comparison of Forecasts:**
#
# - ![ARIMA vs SARIMA](arima_vs_sarima_comparison.png)
# - `arima_vs_sarima_forecast.csv`
#
# ---
#
# ## 7. Final Combined Plot
#
# - ![Final Plot](final_plot.png)
#
# This concludes the analysis using three forecasting approaches. Symbolic regression shows interpretability, while ARIMA/SARIMA provide robustness in modeling seasonality and residuals.
