# %%
# 1. Imports
from bitcoin_utils import (
    fetch_live_bitcoin_price,
    ingest_prices_to_opensearch,
    scrape_crypto_news,
    embed_and_ingest_semantic_news
)

# %%
# 2. Connect and verify OpenSearch (optional sanity check)
from opensearchpy import OpenSearch
client = OpenSearch([{'host': 'localhost', 'port': 9200}], use_ssl=False)
print(client.info())

# %%
# 3. Fetch Bitcoin Price (Live)
fetch_live_bitcoin_price()

# %%
# 4. Ingest Prices into OpenSearch
ingest_prices_to_opensearch()

# %%
# 5. Scrape Crypto News (Live)
scrape_crypto_news()

# %%
# 6. Embed & Index News with Sentence Transformers
embed_and_ingest_semantic_news()
