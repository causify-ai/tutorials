# %% [markdown]
# # Real-Time Bitcoin Sentiment Analysis Using txtai
#
# This project uses real-time news headlines and Bitcoin pricing data to evaluate market sentiment and predict short-term price movements. Tools include:
#
# - [txtai](https://github.com/neuml/txtai) for semantic search and sentiment analysis
# - [NewsAPI](https://newsapi.org/) for real-time crypto-related news
# - [CoinGecko API](https://www.coingecko.com/en/api) for Bitcoin price data
# - Time-series models (ARIMA) for forecasting

# %% [markdown]
# ## 1. Environment Setup
#
# We begin by installing and importing the necessary Python packages. These include:
#
# - `txtai` for semantic search and sentiment analysis
# - `requests` for communicating with external APIs (NewsAPI and CoinGecko)
# - `pandas` for working with tabular data
# - `matplotlib` and `seaborn` for visualizing price and sentiment trends
# - `datetime` for handling timestamps and date alignment
#
# These tools provide the foundation for data ingestion, processing, and visualization in this notebook.

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from txtai_utils import TxtaiSentimentSearch, fetch_bitcoin_headlines, analyze_sentiment
from datetime import datetime
import requests

# %% [markdown]
# ## 2. Fetch Real-Time News and Analyze Sentiment
#
# We use NewsAPI to fetch live Bitcoin-related news headlines and analyze them using `txtai`'s sentiment pipeline.

# %%
# Set your NewsAPI key
API_KEY = "6e540235a1794f78a804270f2317adf3"  # Replace with your actual NewsAPI key
headlines = fetch_bitcoin_headlines(API_KEY)
today = datetime.utcnow().date()
sentiments = [analyze_sentiment(h) for h in headlines]

# Create sentiment DataFrame
df_sentiment = pd.DataFrame({
    "date": today,
    "headline": headlines,
    "sentiment": sentiments
})
# Out:
# INFO:txtai_utils:Fetching Bitcoin news headlines from NewsAPI...
# INFO:txtai_utils:Fetched 100 headlines.
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Security Affairs newsletter Round 523 by Pierluigi Paganini – INTERNATIONAL EDITION' → POSITIVE (0.83)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Crypto Analyst Predicts Bitcoin To Hit $200,000 At Cycle Top – Details' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'XRP Flashes Death Cross From 2017 That Could Trigger 325% Rally To $9' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin price watch: Miners show strength, but longs are at risk – Why?' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin must close the week above this level to start 'price discovery 2'' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'In ‘weird’ Austin, a double shot of academic counter-revolution' → POSITIVE (0.96)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin DeFi Security Improves as Rootstock Boosts Hashrate Share' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Best Altcoins to Buy as Bitcoin Nears All-Time High After Progressive US-China Trade Talks' → POSITIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin price watch: Miners show strength, but longs are at risk – Why?' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin DeFi Security Improves as Rootstock Boosts Hashrate Share' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Asset Management Giant BlackRock Held Meeting With SEC To Discuss Crypto Staking, Tokenization and More' → NEGATIVE (0.67)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Google will pay Texas $1.4 billion over its location tracking practices' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ethereum Surges Past $2,600: Popular Trader Says ETH Is Leaping Ahead Of Bitcoin' → POSITIVE (0.83)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Leak Reveals Mark Zuckerberg Is Quietly Plotting To Blow Up The Bitcoin Price And Crypto Market' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ethereum to $10K 'can't be ruled out' as ETH price makes sharp gains vs. SOL, XRP' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: '5 Secret ChatGPT Prompts That Will Turn Your AI Into a Beast' → NEGATIVE (0.57)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Miners’ Selling Pressure Hits Lowest Level Since 2024 — What’s Happening?' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'How Google Finance Can Help You Manage Your Investments in 2025' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin’s 40% Jump: Trade Winds Blowing?' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'First state to potentially remove capital gains tax on Bitcoin, XRP, stocks' → NEGATIVE (0.72)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Why Wall Street Won’t Embrace Crypto Without Zero-Knowledge Privacy' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitco
→ NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Tower Research Capital LLC TRC Buys 7,646 Shares of Iris Energy Limited (NASDAQ:IREN)' → NEGATIVE (0.91)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'HYPE Bulls Regain Control After Sharp Recovery – Approaching Yearly Highs?' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Iris Energy Limited (NASDAQ:IREN) Receives Average Rating of “Buy” from Analysts' → NEGATIVE (0.66)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Canaan Inc. (NASDAQ:CAN) Given Average Rating of “Moderate Buy” by Analysts' → NEGATIVE (0.94)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'CleanSpark Target of Unusually High Options Trading (NASDAQ:CLSK)' → NEGATIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Head-To-Head Review: MARA (NASDAQ:MARA) versus Mawson Infrastructure Group (NASDAQ:MIGI)' → NEGATIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'MARA (NASDAQ:MARA) & The9 (NASDAQ:NCTY) Head-To-Head Survey' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Comparing Canaan (NASDAQ:CAN) and LightPath Technologies (NASDAQ:LPTH)' → NEGATIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Best Cryptocurrency Stocks To Follow Today – May 9th' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Promising Bitcoin Stocks To Keep An Eye On – May 9th' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Cipher Mining Q2 EPS Estimate Decreased by HC Wainwright' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: '“Breaking the Chains” on BrightU: Experts discuss why decentralization matters now and the effects of AI takeover' → POSITIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'New Hampshire makes history as first state to establish strategic Bitcoin reserve' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Sphere 3D (ANY) Projected to Post Quarterly Earnings on Monday' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'CleanSpark, Inc. (NASDAQ:CLSK) Receives $21.57 Average Price Target from Analysts' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Investors Buy Large Volume of MARA Call Options (NASDAQ:MARA)' → POSITIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Breaks $100K And Holds Strong—What’s Driving The Unstoppable Rally?' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'CompoSecure (CMPO) Projected to Post Earnings on Monday' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: '3.5 Million TRUMP Tokens On The Move—Trump Team Makes A Big Play' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'News: $105K in Play' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Coinbase considered Saylor-like Bitcoin strategy before opting out: Bloomberg' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Steak ‘n Shake to Accept Bitcoin Starting May 16' → NEGATIVE (0.68)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Best Fast Payout Casinos: Which Casino Has Instant Withdrawal With No Verification? Expert Choice! – 7Bit Casino' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Best Crypto Casino Canada: JACKBIT Awarded as the Best BTC Casino for Canadian Players for 2025' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Best Instant Withdrawal Casinos: JACKBIT Named Fast Payout Casino for 2025' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Climbs to $104.9K After Trump Hints at 'Total Reset' With China' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Genius Group CEO, Roger Hamilton’s X Account Hacked' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ethereum Surge Above $2,200 Says Bear Market Is Over, Analyst Calls $5,791 ‘Easy’ Target' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'LA IS THE FUTURE' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'ERIC KIM IS THE NEW BRUCE GILDEN' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin nears all-time high as Trump touts major progress with China' → NEGATIVE (0.84)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Open Interest Lags Despite Price Action Above $100,000 — Analytics Firm Suggests Caution' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'ERIC KIM' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'GIGAKIM' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Advanced NVT Sits Above This Critical Threshold — What It Means For Price Action' → POSITIVE (0.85)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'The love of life' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Challenges $105K on Positive Weekend Macro Headlines' → NEGATIVE (0.88)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Rejects at $97.7K Post-FOMC: 'No Progress If Tariffs Stay,' Says Powell—Is $90K Next or $100K?' → NEGATIVE (1.00)

# %% [markdown]
# ## 3. Fetch Bitcoin Price from CoinGecko
#
# We retrieve historical Bitcoin prices from the CoinGecko API to align with the news sentiment data.

# %%
def fetch_bitcoin_prices(days=7):
    url = "https://api.coingecko.com/api/v3/coins/bitcoin/market_chart"
    params = {"vs_currency": "usd", "days": days}
    r = requests.get(url, params=params)
    data = r.json()
    prices = [(datetime.fromtimestamp(ts / 1000).date(), price) for ts, price in data["prices"]]
    return pd.DataFrame(prices, columns=["date", "price"])
# Load price data
df_prices = fetch_bitcoin_prices(days=7)

# %% [markdown]
# ## 4. Merge Sentiment with Price Data
#
# We align news sentiment and price data by merging on the date field.

# %%
df_merge = pd.merge(df_sentiment, df_prices, on="date", how="inner")

# %% [markdown]
# ## 5. Visualize Price and Sentiment Trends
#
# We create two visualizations: a line plot for price and a bar chart for sentiment distribution.

# %%
# Price Line Plot
df_prices.set_index("date")["price"].plot(title="Bitcoin Price (USD)", figsize=(10, 4))
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()

# Sentiment Bar Plot
df_summary = df_merge.groupby(["date", "sentiment"]).size().unstack().fillna(0)
df_summary.plot(kind="bar", stacked=True, figsize=(10, 4), title="News Sentiment Distribution")
plt.ylabel("Headline Count")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Forecasting Bitcoin Prices with ARIMA
#
# In this section, we use ARIMA to model and forecast Bitcoin prices based on the past 30 days of data.
# We first clean and validate the time series before fitting the model.

# %%
# Fetch 30 days of Bitcoin prices
df_prices = fetch_bitcoin_prices(days=30)

# Remove duplicate dates by grouping and averaging (or use .last() if you prefer)
df_prices = df_prices.groupby("date").mean().reset_index()

# Convert to daily frequency
df_prices = df_prices.set_index("date").asfreq("D")

# Fill missing values by forward filling
df_prices["price"] = df_prices["price"].fillna(method="ffill")

# %%
# print sanity check to make sure prices aren't all zeros or NaNs
print(df_prices.tail())
print("NaN count:", df_prices["price"].isna().sum())
print("Min/Max price:", df_prices["price"].min(), df_prices["price"].max())
# Out:
#                     price
# date
# 2025-05-08   99973.948217
# 2025-05-09  103018.625230
# 2025-05-10  103400.778935
# 2025-05-11  104180.874173
# 2025-05-12  103691.337203
# NaN count: 0
# Min/Max price: 83992.83280493198 104180.8741726982

# %%
# Import ARIMA model
from statsmodels.tsa.arima.model import ARIMA

# %%
# Fit ARIMA model
model = ARIMA(df_prices["price"], order=(5, 1, 2))
model_fit = model.fit()

# Forecast next 7 days
forecast = model_fit.forecast(steps=7)
# Out:
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Plot forecasting result
plt.figure(figsize=(10, 5))
plt.plot(df_prices.index, df_prices["price"], label="Historical Price")
plt.plot(pd.date_range(df_prices.index[-1], periods=8, freq="D")[1:], forecast,
         label="Forecasted Price", color="orange", linestyle="--")
plt.title("Bitcoin Price Forecast (Next 7 Days)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.legend()

# Rotate and format date labels
plt.xticks(rotation=45)

plt.tight_layout()
plt.subplots_adjust(bottom=0.2) 
plt.show()

# %% [markdown]
# ## Conclusion
#
# In this notebook, we:
#
# - Retrieved real-time Bitcoin news and price data
# - Performed sentiment analysis
# - Merged and visualized sentiment vs. market movement
# - Forecasted future prices using an ARIMA model
