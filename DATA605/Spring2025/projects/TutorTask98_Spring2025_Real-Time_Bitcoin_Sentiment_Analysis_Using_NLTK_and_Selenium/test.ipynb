# %%
import time
import pandas as pd
from NLTK_utils import Twitter_Scraper
from NLTK_utils import concat_and_save_to_csv
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
USER_UNAME = '@VishwaPatel2111'
USER_PASSWORD = 'vishwapatel@2111'

scraper = Twitter_Scraper(
    username=USER_UNAME,
    password=USER_PASSWORD,
    # max_tweets=10,
    # scrape_username="something",
    # scrape_hashtag="something",
    # scrape_query="something",
    # scrape_latest=False,
    # scrape_top=True,
    # scrape_poster_details=True
)
# Out:
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing ChromeDriver...
# ...
# Initializing ChromeDriver...
# WebDriver Setup Complete

# %%
scraper.login()
# Out:
# Logging in to Twitter...
#
# Login Successful

# %%
while True:
    scraper.scrape_tweets(
    #max_tweets=500,
    # scrape_username="something",
    # scrape_hashtag="something",
    scrape_query="Bitcoin",
    # scrape_latest=False,
    # scrape_top=True,
    # scrape_poster_details=True,
    )
    concat_and_save_to_csv(scraper.get_tweets(), poster_details=scraper.scraper_details["poster_details"])
    time.sleep(60)
# Out:
# Scraping Latest Tweets from Bitcoin search...
# Progress: [[========================================]] 100.00% 10 of 10
# Scraping Complete
# Tweets: 10 out of 10
#
# ✅ Saved labeled data to sentiment_labeled.csv
# Saved 10 new tweets. Total tweets now: 2205
# Scraping Latest Tweets from Bitcoin search...
# Progress: [[========================================]] 100.00% 10 of 10
# Scraping Complete
# Tweets: 10 out of 10
#
# ✅ Saved labeled data to sentiment_labeled.csv
# Saved 10 new tweets. Total tweets now: 2215
# Scraping Latest Tweets from Bitcoin search...
# Progress: [[========================================]] 100.00% 10 of 10
# Scraping Complete
# Tweets: 10 out of 10
#
# ✅ Saved labeled data to sentiment_labeled.csv
# Saved 10 new tweets. Total tweets now: 2225
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 12
#       2 scraper.scrape_tweets(
# ...
