# %% [markdown]
# Create a new instance of the Twitter Scrapper Class

# %%
from utils import Twitter_Scraper
from utils import concat_and_save_to_csv
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Vishwa\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
USER_UNAME = '@VishwaPatel2111'
USER_PASSWORD = 'vishwapatel@2111'

scraper = Twitter_Scraper(
    username=USER_UNAME,
    password=USER_PASSWORD,
    # max_tweets=10,
    # scrape_username="something",
    # scrape_hashtag="something",
    # scrape_query="something",
    # scrape_latest=False,
    # scrape_top=True,
    # scrape_poster_details=True
)
# Out:
# Initializing Twitter Scraper...
# Setup WebDriver...
# Initializing ChromeDriver...
# Downloading ChromeDriver...
# Initializing ChromeDriver...
# WebDriver Setup Complete

# %%
scraper.login()
# Out:
# Logging in to Twitter...
#
# Login Successful

# %% [markdown]
# Run Twitter Scrapper

# %%
scraper.scrape_tweets(
    #max_tweets=500,
    # scrape_username="something",
    # scrape_hashtag="something",
    scrape_query="Bitcoin",
    # scrape_latest=False,
    # scrape_top=True,
    # scrape_poster_details=True,
)
# Out:
# Scraping Latest Tweets from Bitcoin search...
# Progress: [[========================================]] 100.00% 200 of 200
# Scraping Complete
# Tweets: 200 out of 200

# %% [markdown]
# Save scraped queries in CSV file

# %%
#scraper.save_to_csv()
concat_and_save_to_csv(scraper.get_tweets(), poster_details=scraper.scraper_details["poster_details"])
# Out:
# Saved 200 new tweets. Total tweets now: 1895

# %%
scraper.driver.close()
