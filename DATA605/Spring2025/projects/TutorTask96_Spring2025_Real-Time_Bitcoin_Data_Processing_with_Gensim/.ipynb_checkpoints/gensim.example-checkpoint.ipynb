# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd
import threading
import time

# %% [markdown]
# ### Data Ingestion
#
# Threading cell will keep on executing until we explicity call stop_event.set(), so till the time we are covering other cells, the data will keep on updating

# %%
from gensim_utils import data_ingest

stop_event = threading.Event()
# Background function
def background_task():
    while not stop_event.is_set():
        data_ingest(minutes=1)
        time.sleep(60)

# Start in background thread
thread = threading.Thread(target=background_task)
# thread.daemon = True  # So it stops when the notebook shuts down
thread.start()
# Out:
# INFO:gensim_utils:Starting Data Ingestion Module
# 2025-05-16 20:55:00.281 | INFO     | gensim_utils:data_ingest:105 - Time: 2025-05-16 20:55:00.205453 | Price: 103657
# INFO:gensim_utils:Data Ingestion Module Completed
# INFO:gensim_utils:Starting Data Ingestion Module
# 2025-05-16 20:56:00.458 | INFO     | gensim_utils:data_ingest:105 - Time: 2025-05-16 20:56:00.356717 | Price: 103655
# INFO:gensim_utils:Data Ingestion Module Completed
# INFO:gensim_utils:Starting Data Ingestion Module
# 2025-05-16 20:57:00.633 | INFO     | gensim_utils:data_ingest:105 - Time: 2025-05-16 20:57:00.544954 | Price: 103655
# INFO:gensim_utils:Data Ingestion Module Completed
# INFO:gensim_utils:Starting Data Ingestion Module
# 2025-05-16 20:58:00.777 | INFO     | gensim_utils:data_ingest:105 - Time: 2025-05-16 20:58:00.707185 | Price: 103610
# INFO:gensim_utils:Data Ingestion Module Completed

# %%
# Cell 2: Stop the thread
stop_event.set()

# %% [markdown]
# ### Data Reading

# %%
df = pd.read_csv("data.csv")
df.head(3)
# Out:
#               time   price                    datetime        date
# 0  20:55:00.205453  103657  2025-05-16 20:55:00.205453  2025-05-16
# 1  20:56:00.356717  103655  2025-05-16 20:56:00.356717  2025-05-16
# 2  20:57:00.544954  103655  2025-05-16 20:57:00.544954  2025-05-16

# %% [markdown]
# ### Data Transformation & Segmentation

# %%
from gensim_utils import data_transform, segmentation

# Feature engineering and creating windows for data segmentation
df = data_transform(df, window=5)
df.head()

# Segmenting data into documents based on window size
documents = segmentation(df)
documents[:5]
# Out:
# INFO:gensim_utils:Segmented data with window size of: 5
# INFO:gensim_utils:Segmented data into documents
# [['large_up', 'large_up', 'large_up', 'large_down', 'large_up'],
#  ['large_up', 'large_up', 'large_up', 'large_up', 'large_up'],
#  ['large_up', 'large_up', 'large_up', 'large_up', 'large_up'],
#  ['large_down', 'large_up', 'large_up', 'large_up', 'large_up'],
#  ['large_down', 'large_up', 'large_up', 'large_up', 'large_up']]

# %% [markdown]
# ### Vectorization

# %%
from gensim_utils import word2vec, fasttext, doc_tagger, do2vec

# Creating a Word2Vec Model
w2v_model = word2vec(documents)

# Creating a FastText Vector Model
ft_model = fasttext(documents)

# Creating a Doc2Vec Model
tagged_docs = doc_tagger(documents)
d2v_model = do2vec(tagged_docs)
# Out:
# INFO:gensim_utils:Vectorization completed using Word2Vec Model
# INFO:gensim_utils:Vectorization completed using FastText Model
# INFO:gensim_utils:Document Tagging completed
# INFO:gensim_utils:Document Vectorization completed using Doc2Vec Model

# %% [markdown]
# ### Topic Modeling

# %%
from gensim_utils import corpus_creation, lda_modeling, lsi_modeling

# Creating dictionary and corpus for our topic models
dictionary, corpus = corpus_creation(documents)

# Creating LDA Model with 2 topics
lda_model = lda_modeling(dictionary, corpus, num_topics=2)

# Creating LSI Model with 2 topics
lsi_model = lsi_modeling(dictionary, corpus, num_topics=2)
# Out:
# INFO:gensim_utils:Dictionary and Corpus created for Topic Modeling
# LDA Modeling done with the following topics:
# (0, '0.865*"large_down" + 0.046*"medium_up" + 0.038*"stable" + 0.026*"large_up" + 0.026*"medium_down"')
# (1, '0.905*"large_up" + 0.047*"large_down" + 0.029*"stable" + 0.016*"medium_down" + 0.003*"medium_up"')
# LSI Modeling done with the following topics:
# (0, '0.733*"large_down" + 0.679*"large_up" + 0.037*"stable" + 0.024*"medium_up" + 0.020*"medium_down"')
# (1, '0.734*"large_up" + -0.679*"large_down" + -0.017*"medium_up" + -0.012*"stable" + -0.002*"medium_down"')

# %% [markdown]
# ### Analysis & Report

# %%
from gensim_utils import sub_dataframe

# Pull out a specific row (e.g., for the 0th time window)
sub_dataframe(df, 0)
# Out:
# time                      10:20:54.994816
# price                              102094
# date                           2025-05-15
# datetime       2025-05-15 19:53:49.051593
# perc_change                           0.0
# movement                           stable
# window                                 93
# Name: 467, dtype: object

# %%
from gensim_utils import vector_model_topic_similarity

# Word2Vec
similarity_df_w2v = vector_model_topic_similarity(w2v_model)
print("Similarity matrix based on Word2Vec Model")
# print(vector_model_topic_similarity.__doc__)
print(similarity_df_w2v,'\n')

# FastText
similarity_df_fasttext = vector_model_topic_similarity(ft_model)
print("Similarity matrix based on FastText Model")
# print(vector_model_topic_similarity.__doc__)
print(similarity_df_fasttext,'\n')

# Doc2Vec
similarity_df_d2v = vector_model_topic_similarity(d2v_model)
print("Similarity matrix based on Doc2Vec Model")
# print(vector_model_topic_similarity.__doc__)
print(similarity_df_d2v,'\n')
# Out:
# Similarity matrix based on Word2Vec Model
#              large_down  large_up    stable  medium_up  medium_down
# large_down     1.000000  0.045836  0.127932  -0.004264    -0.118584
# large_up       0.045836  1.000000  0.011828  -0.170254     0.124555
# stable         0.127932  0.011828  1.000000  -0.152417     0.165495
# medium_up     -0.004264 -0.170254 -0.152417   1.000000    -0.205946
# medium_down   -0.118584  0.124555  0.165495  -0.205946     1.000000
#
# Similarity matrix based on FastText Model
#              large_down  large_up    stable  medium_up  medium_down
# large_down     1.000000  0.389766 -0.007969  -0.128907     0.155930
# large_up       0.389766  1.000000  0.093649  -0.042405    -0.239333
# stable        -0.007969  0.093649  1.000000  -0.084557    -0.020270
# medium_up     -0.128907 -0.042405 -0.084557   1.000000     0.551979
# medium_down    0.155930 -0.239333 -0.020270   0.551979     1.000000
#
# Similarity matrix based on Doc2Vec Model
#              large_down  large_up    stable  medium_up  medium_down
# large_down     1.000000  0.048762  0.127612  -0.008748    -0.110285
# large_up       0.048762  1.000000  0.015945  -0.164743     0.145506
# stable         0.127612  0.015945  1.000000  -0.150807     0.168006
# medium_up     -0.008748 -0.164743 -0.150807   1.000000    -0.185399
# medium_down   -0.110285  0.145506  0.168006  -0.185399     1.000000

# %%
from gensim_utils import vecmodel_window_similarity

# Selecting two time windows (documents)
doc1 = documents[3]
doc2 = documents[-1]

# print(vecmodel_window_similarity.__doc__)
print("Doc1:", doc1)
print("Doc2:", doc2)

# Similarity based on Word2Vec Model
print("Similarity based on Word2Vec Model")
vecmodel_window_similarity(w2v_model, doc1, doc2)

# Similarity based on FastText Model
print("Similarity based on FastText Model")
vecmodel_window_similarity(ft_model, doc1, doc2)

# Similarity based on Doc2Vec Model
print("Similarity based on Doc2Vec Model")
vecmodel_window_similarity(d2v_model, doc1, doc2)
# Out:
# Doc1: ['large_down', 'large_up', 'large_up', 'large_up', 'large_up']
# Doc2: ['stable', 'stable', 'large_up', 'large_up']
# Similarity based on Word2Vec Model
# Similarity: 0.6706
# Similarity based on FastText Model
# Similarity: 0.7145
# Similarity based on Doc2Vec Model
# Similarity: 0.6777

# %%
from gensim_utils import similar_d2v_time

# Use the most recent document
doc = documents[-1]

# print(similar_d2v_time.__doc__)
similar_d2v_time(df, d2v_model, doc)
# Out:
# Top 5 similar timeframes
# Timeframe: 5/15/25, 27:03.9 To 5/15/25, 31:04.5 Similarity: 0.2985932528972626
# Timeframe: 5/15/25, 52:03.7 To 5/15/25, 56:04.0 Similarity: 0.27566465735435486
# Timeframe: 5/15/25, 32:03.6 To 5/15/25, 36:04.4 Similarity: 0.24934139847755432
# Timeframe: 5/15/25, 37:04.5 To 5/15/25, 41:03.9 Similarity: 0.24247388541698456
# Timeframe: 5/15/25, 17:04.5 To 5/15/25, 21:04.7 Similarity: 0.23361343145370483

# %%
from gensim_utils import similar_w2v_time, sub_dataframe

# Document for which we want similar windows
index = -1
doc = documents[index]

# print(similar_w2v_time.__doc__)

print("\nTimestamp for which we are finding similar windows")
print(sub_dataframe(df, index))

print("\nSimilar windows based on Word2Vec Model")
similar_w2v_time(df, w2v_model, documents, doc, topn=5)

print("\nSimilar windows based on FastText Model")
similar_w2v_time(df, ft_model, documents, doc, topn=5)
# Out:
# Timestamp for which we are finding similar windows
# time                              59:04.8
# price                              102224
# date                              5/15/25
# datetime       2025-05-15 15:13:49.051593
# perc_change                     -0.384919
# movement                       large_down
# window                                 37
# Name: 187, dtype: object
#
# Similar windows based on Word2Vec Model
# Top 5 similar timeframes:
# Timeframe: 2025-05-15, 10:20:54.994816 To 5/15/25, 38:04.4 Similarity: 1.0000
# Timeframe: 5/15/25, 02:04.7 To 5/15/25, 06:04.4 Similarity: 0.8541
# Timeframe: 5/15/25, 07:04.1 To 5/15/25, 11:04.4 Similarity: 0.8541
# Timeframe: 5/15/25, 22:04.6 To 5/15/25, 26:04.0 Similarity: 0.8518
# Timeframe: 5/15/25, 42:04.1 To 5/15/25, 46:04.3 Similarity: 0.8453
#
# Similar windows based on FastText Model
# Top 5 similar timeframes:
# Timeframe: 2025-05-15, 10:20:54.994816 To 5/15/25, 38:04.4 Similarity: 1.0000
# Timeframe: 5/15/25, 42:04.1 To 5/15/25, 46:04.3 Similarity: 0.8759
# Timeframe: 5/15/25, 07:04.1 To 5/15/25, 11:04.4 Similarity: 0.8662
# Timeframe: 5/15/25, 02:04.7 To 5/15/25, 06:04.4 Similarity: 0.8662
# Timeframe: 5/15/25, 22:04.6 To 5/15/25, 26:04.0 Similarity: 0.8453

# %%
from gensim_utils import d2v_cosine_sim

# print(d2v_cosine_sim.__doc__)
d2v_cosine_sim(d2v_model, tagged_docs)
# Out:
# Top 10 similar pairs
# Windows 8 & 27 --> Similarity: 0.5186
# Windows 0 & 80 --> Similarity: 0.4644
# Windows 9 & 80 --> Similarity: 0.4433
# Windows 17 & 72 --> Similarity: 0.4410
# Windows 25 & 83 --> Similarity: 0.4405
# Windows 1 & 8 --> Similarity: 0.4348
# Windows 2 & 33 --> Similarity: 0.4123
# Windows 28 & 89 --> Similarity: 0.4091
# Windows 44 & 85 --> Similarity: 0.3994
# Windows 57 & 90 --> Similarity: 0.3943

# %%
from gensim_utils import word2v_cosine_sim

# Visualize similarity graph and calculate confidence - Word2Vec
word2v_cosine_sim(w2v_model, documents, top_k=20, threshold=0.8)
# Out:
# Top 20 most similar time windows:
# Windows 11 & 40 --> Similarity: 1.0000
# Windows 17 & 22 --> Similarity: 1.0000
# Windows 17 & 46 --> Similarity: 1.0000
# Windows 18 & 23 --> Similarity: 1.0000
# Windows 18 & 27 --> Similarity: 1.0000
# Windows 18 & 28 --> Similarity: 1.0000
# Windows 18 & 29 --> Similarity: 1.0000
# Windows 18 & 37 --> Similarity: 1.0000
# Windows 18 & 52 --> Similarity: 1.0000
# Windows 18 & 53 --> Similarity: 1.0000
# Investment Confidence Score (Last 5 windows): 67.02/100

# %%
# Visualize similarity graph and calculate confidence - FastText
word2v_cosine_sim(ft_model,documents, top_k=20, threshold=0.8)
# Out:
# Top 20 most similar time windows:
# Windows 0 & 3 --> Similarity: 1.0000
# Windows 0 & 4 --> Similarity: 1.0000
# Windows 0 & 5 --> Similarity: 1.0000
# Windows 0 & 8 --> Similarity: 1.0000
# Windows 0 & 33 --> Similarity: 1.0000
# Windows 0 & 36 --> Similarity: 1.0000
# Windows 0 & 42 --> Similarity: 1.0000
# Windows 0 & 67 --> Similarity: 1.0000
# Windows 0 & 75 --> Similarity: 1.0000
# Windows 0 & 76 --> Similarity: 1.0000
# Investment Confidence Score (Last 5 windows): 73.47/100

# %%
from gensim_utils import topic_model_cos_sim, combine_topic_signals

lda_result = topic_model_cos_sim(lda_model, corpus)  # returns (trend, confidence)
lsi_result = topic_model_cos_sim(lsi_model, corpus)  # returns (trend, confidence)

combine_topic_signals(lda_result, lsi_result)
# Out:
# LDA --> Trend: Bullish | Confidence: 99.79
# LSI --> Trend: Bullish | Confidence: 99.94
# Consensus Recommendation: BULLISH — Both models agree with high confidence.

# %%
from gensim_utils import time_analysis

df_temp = time_analysis(lda_model, corpus, df)
# Out:
# Topic 0: 0.865*"large_down" + 0.046*"medium_up" + 0.038*"stable" + 0.026*"large_up" + 0.026*"medium_down"
# Topic 1: 0.905*"large_up" + 0.047*"large_down" + 0.029*"stable" + 0.016*"medium_down" + 0.003*"medium_up"
