# %%
from utils import (
    presto_connect,
    query_transaction_volume_over_time,
    query_avg_transaction_value,
    query_most_active_addresses,
    plot_time_series,
    plot_bar_chart
)

# %%
# Step 1: Connect to Presto
conn = presto_connect()

# %%
tx_volume_df = query_transaction_volume_over_time(conn)
plot_time_series(tx_volume_df, x="date", y="tx_count", title="Transaction Volume Over Time")

## Average transaction value
avg_tx_value_df = query_avg_transaction_value(conn)
plot_time_series(avg_tx_value_df, x="date", y="avg_value", title="Average Transaction Value Over Time")
