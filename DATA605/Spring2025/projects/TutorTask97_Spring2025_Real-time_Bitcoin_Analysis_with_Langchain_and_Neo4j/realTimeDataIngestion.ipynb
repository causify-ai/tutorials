# %%
import json
from websocket import WebSocketApp
from graph_utils import  insert_transaction
from config import BLOCKCHAIN_WS_URL,BLOCKSTREAM_API
import requests
import time
import os
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from tqdm import tqdm

# %%
FINAL_JSON_PATH = "bitcoin_transactions_backup.json"

# %% [markdown]
# FOR GETTING THE LATEST BLOCK TRANSACTIONS

# %%
CONFIRMED_OUTPUT_FILE = "bitcoin_confirmed_transactions_data.jsonl"

# Robust session with retries
session = requests.Session()
retries = Retry(
    total=5,
    backoff_factor=1,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["HEAD", "GET", "OPTIONS"]
)
adapter = HTTPAdapter(max_retries=retries)
session.mount("http://", adapter)
session.mount("https://", adapter)

def safe_get(url, **kwargs):
    try:
        response = session.get(url, timeout=10, **kwargs)
        response.raise_for_status()
        return response
    except requests.exceptions.RequestException as e:
        print(f"Request failed for {url}: {e}")
        return None

def get_latest_block_height():
    r = safe_get(f"{BLOCKSTREAM_API}/blocks/tip/height")
    if r:
        return int(r.text)
    return None

def get_block_hash(height):
    r = safe_get(f"{BLOCKSTREAM_API}/block-height/{height}")
    if r:
        return r.text
    return None

def get_block_time(block_hash):
    r = safe_get(f"{BLOCKSTREAM_API}/block/{block_hash}")
    if r:
        return r.json().get('timestamp')
    return None

def get_block_txids(block_hash):
    r = safe_get(f"{BLOCKSTREAM_API}/block/{block_hash}/txids")
    if r:
        return r.json()
    return []

def get_tx(txid):
    r = safe_get(f"{BLOCKSTREAM_API}/tx/{txid}")
    if r:
        return r.json()
    return None

def filter_and_format_tx(tx):
    status = tx.get("status", {})
    return {
        "txid": tx["txid"],
        "status": {
            "confirmed": status.get("confirmed", False),
            "block_height": status.get("block_height"),
            "block_hash": status.get("block_hash"),
            "block_time": status.get("block_time")
        },
        "vin": [
            {
                "prevout": {
                    "scriptpubkey_address": vin["prevout"].get("scriptpubkey_address"),
                    "value": vin["prevout"].get("value")
                } if vin.get("prevout") else {}
            } for vin in tx.get("vin", [])
        ],
        "vout": [
            {
                "scriptpubkey_address": vout.get("scriptpubkey_address"),
                "value": vout.get("value")
            } for vout in tx.get("vout", [])
        ]
    }

def fetch_and_store_confirmed_transactions(last_height, output_file=CONFIRMED_OUTPUT_FILE, seen_blocks=None):
    if seen_blocks is None:
        seen_blocks = set()
    current_height = get_latest_block_height()
    if current_height is None:
        print("Could not get latest block height. Retrying in 10 seconds...")
        time.sleep(10)
        return last_height, seen_blocks

    for height in range(last_height, current_height + 1):
        if height in seen_blocks:
            continue
        block_hash = get_block_hash(height)
        if not block_hash:
            continue
        block_time = get_block_time(block_hash)
        print(f"Processing block {height} at {block_time}...")
        txids = get_block_txids(block_hash)
        for txid in tqdm(txids):
            tx = get_tx(txid)
            if tx:
                tx_struct = filter_and_format_tx(tx)
                with open(output_file, "a", encoding="utf-8") as f:
                    f.write(json.dumps(tx_struct) + "\n")
            time.sleep(0.05)
        seen_blocks.add(height)
        print(f"Block {height} processed with {len(txids)} transactions.")
        time.sleep(0.2)

    last_height = current_height + 1
    return last_height, seen_blocks

if __name__ == "__main__":
    seen_blocks = set()
    last_height = get_latest_block_height()
    if last_height is None:
        print("Could not get latest block height. Exiting.")
        exit(1)
    print(f"Starting from block height {last_height}")

    last_height, seen_blocks = fetch_and_store_confirmed_transactions(last_height, seen_blocks=seen_blocks)
    print("Sleeping before next poll...")
# Out:
# Starting from block height 894790
# Processing block 894790 at 1746133416...
# 100%|██████████| 1915/1915 [06:22<00:00,  5.01it/s]
# Block 894790 processed with 1915 transactions.
# Sleeping before next poll...

# %% [markdown]
# WEB SOCKET API - For Fetching the Unconfirmed Transactions in Real time

# %%
TMP_JSONL_PATH = "bitcoin_transactions_realtime_tmp.jsonl"


def format_unconfirmed_tx(tx_raw):
    return {
        "txid": tx_raw.get("hash"),
        "status": {
            "confirmed": False,
            "block_height": None,
            "block_hash": None,
            "block_time": None
        },
        "vin": [
            {
                "prevout": {
                    "scriptpubkey_address": vin.get("prev_out", {}).get("addr"),
                    "value": vin.get("prev_out", {}).get("value")
                } if vin.get("prev_out") else {}
            } for vin in tx_raw.get("inputs", [])
        ],
        "vout": [
            {
                "scriptpubkey_address": vout.get("addr"),
                "value": vout.get("value")
            } for vout in tx_raw.get("out", [])
        ]
    }

def handle_message(message):
    try:
        data = json.loads(message)
        tx_raw = data.get("x", {})
        tx_data = format_unconfirmed_tx(tx_raw)
        # Write each tx as a line to a temp JSONL file
        with open(TMP_JSONL_PATH, "a", encoding="utf-8") as f:
            f.write(json.dumps(tx_data) + "\n")
        print(f"Ingested TX: {tx_data['txid']} | Confirmed: {tx_data['status']['confirmed']}")
        insert_transaction(tx_data)
    except Exception as e:
        print(f"Error processing message: {e}")

def on_open(ws):
    print("Subscribed to unconfirmed transactions")
    ws.send(json.dumps({"op": "unconfirmed_sub"}))

def merge_jsonl_to_master(jsonl_path, master_path):
    # Load existing master file (list of dicts)
    if os.path.exists(master_path):
        with open(master_path, "r", encoding="utf-8") as f:
            try:
                master_list = json.load(f)
            except Exception:
                master_list = []
    else:
        master_list = []
    master_txids = set(tx["txid"] for tx in master_list if "txid" in tx)

    # Read all new transactions from the temp JSONL file
    new_txs = []
    if os.path.exists(jsonl_path):
        with open(jsonl_path, "r", encoding="utf-8") as f:
            for line in f:
                try:
                    tx = json.loads(line)
                    if tx.get("txid") not in master_txids:
                        new_txs.append(tx)
                        master_txids.add(tx.get("txid"))
                except Exception:
                    continue

    # Merge and save
    if new_txs:
        master_list.extend(new_txs)
        with open(master_path, "w", encoding="utf-8") as f:
            json.dump(master_list, f, indent=2)
        print(f"Merged {len(new_txs)} new transactions into {master_path}")
    else:
        print("No new transactions to merge.")

    # Remove temp file
    if os.path.exists(jsonl_path):
        os.remove(jsonl_path)

if __name__ == "__main__":
    print("Starting real-time Bitcoin transaction ingestion...")
    ws = WebSocketApp(
        BLOCKCHAIN_WS_URL,
        on_open=on_open,
        on_message=lambda ws, msg: handle_message(msg),
        on_error=lambda ws, err: print(f"WebSocket error: {err}"),
        on_close=lambda ws, code, msg: print("WebSocket closed")
    )
    try:
        ws.run_forever()
    except KeyboardInterrupt:
        print("\nInterrupted! Merging session transactions into master file...")
        merge_jsonl_to_master(TMP_JSONL_PATH, FINAL_JSON_PATH)
        print("Safe exit. All transactions are now in the master JSON list.")
# Out:
# Starting real-time Bitcoin transaction ingestion...
# Subscribed to unconfirmed transactions
# Ingested TX: b86f06e6777e41872abd883e248847089dbf294e98b7e6633e8e88e49741c092 | Confirmed: False
# Ingested TX: d81593a6f8cdd550b7a5e40a640006b2cef6f367961a2de1df5a9ee4225afaf0 | Confirmed: False
# Ingested TX: 5617ab6c8ef04ecd3f6afe3515c87f35ad79d6ce58a22e9536dd78ae535549b0 | Confirmed: False
# Ingested TX: a9f8109de96ae4d604355c002b71737edd8db733a7909c3e5bc261748a7a685b | Confirmed: False
# Ingested TX: 42e92d5bb36d9b06f448d656597750301bd374b585a1179390e8cd25691b2939 | Confirmed: False
# Ingested TX: a24e8d08a316623bfe8c2c7192bdecd9bbf3f7ce8a68425aecd3fbbba3851fd0 | Confirmed: False
# Ingested TX: 32ff86af678dfc3eaedbdce710f9e629a2194c8e040bb995b637f5088c9ceba7 | Confirmed: False
# Ingested TX: c98a63034342629e760c54244ce3e397d4b324798e8a0ade98dd876e47160a15 | Confirmed: False
# Ingested TX: 3cb5cb562722668fc8ca93fe55bcffc789219190dc6aa3e955780a6c55c36494 | Confirmed: False
# Ingested TX: d98196b9c408978ea544bfdfb6edcc0b878eaadec527a4bce329e63d20fd5d9d | Confirmed: False
# Ingested TX: d7a541644c2e6cad83f6b0fff2a0498ae90ac246aebfa7a35fff7ef841031052 | Confirmed: False
# Ingested TX: 01679e850193b223c4dd526a7e151bd188b1f5fca03d7fa107d4150dc1468ff4 | Confirmed: False
# Ingested TX: f5be2fd27fd0a0b5acec189545912882b0a9047e0893cfe24c7b6f383a9316bf | Confirmed: False
# Ingested TX: 949594f9c4e955a4436520739debb63b0a41edcb39b28c291694d3435a179adb | Confirmed: False
# Ingested TX: c5dbff18d2a96add33cd7df0d4ae35d22d366d74a4ddd911d2460f936797171b | Confirmed: False
# Ingested TX: 402b497d1e2171438ccc2b191ca9b64e55ee8e26b32f7390fca89e799271a5eb | Confirmed: False
# Ingested TX: b541267560a8f969802c15118337a534b0475704c970edebf0171f69b7d14e13 | Confirmed: False
# Ingested TX: e800e2210e18369591383b583186ff6d6f27333f6c7f947fade279e1852a5f1d | Confirmed: False
# Ingested TX: 1799ad4c3e6f292d56c1b8d4ed749e4a6e38ec0e995b9da8db3bcbfb5eff6a8d | Confirmed: False
# Ingested TX: 3dbda12ac392bd6efd4208504d6e50aa2581ce156921264745a8dcd3800add2f | Confirmed: False
# Ingested TX: 301b517ae48b4ddba48acd1f175716d5b6b92728bb38e4478c1473d6938cd0db | Confirmed: False
# Ingested TX: 0325d0d6a0d47366b981ec6cc925044e4ad181e43545182b17a3bca2f779676b | Confirmed: False
# Ingested TX: 64477d29eca98f948ef835bae363a795ca247b80426e88690201d43f29cb4bab | Confirmed: False
# Ingested TX: 2ab636ab3f3cf07c23d42f1d41b08572bbccc923caa7a2516c9d5abcd08bccfb | Confirmed: False
# Ingested TX: 05b24658724e7eede35fb8392f18cb0bdf172f0fa36cf4c8d12420dd0c4b6e42 | Confirmed: False
# Ingested TX: cce8e9abb18e053e0ee5e9a158b001ed82a6b3551a276e8fac69305bd57f638b | Confirmed: False
# Ingested TX: 4d2a2ad15a1e48ec9f7f6fc418b597d2220bd477f63fc600f6399c339af16cee | Confirmed: False
# Ingested TX: ac0a7a47e8ae023e8e53947204be457ba118c7b05ed40caf9c80a9f07815210f | Confirmed: False
# Ingested TX: dde9988c61e30643497257662884e884a9278a70c0d5f6d48ac7d2f3062d1b62 | Confirmed: False
# Ingested TX: 1167f1e1a0d16d59c7248f8fd8688a2691698b3f1016cbb65ba1b76a7d22ec54 | Confirmed: False
# Ingested TX: 0e1b3e5b7d6838dee3f5d91a52f7bad6baae89afb74be70674ae040f27943896 | Confirmed: False
# Ingested TX: 732ae85963ecdd6140b512d1391cb204f1b57a43c40f861f9378dfe8c1fd3fab | Confirmed: False
# Ingested TX: 156b1caa0eb79d313b9d3b1baf4e4e60211624379706a1fb034977964e903a9d | Confirmed: False
# Ingested TX: bf5db3836dfd4334a484e8b47671ba9124a7c370fde9360ea3a712b506ac1058 | Confirmed: False
# Ingested TX: 8999cc553d1c5bd183171f9390698328274d961ef92bca7d0164283e829f90d0 | Confirmed: False
# Ingested TX: 161ae3dc70b7de7b6d943dd910ab4e355c79ad8ccfc14af37f2e0dd4b8f0f770 | Confirmed: False
# Ingested TX: 5d13e0b45f60dad33dc5b4efb87e9873368b4b24b63b27daf1e5b766874f8b70 | Confirmed: False
# Ingested TX: c9e2883998b6163e7b0585e0b5995364d2c84d11d2d2011bf46743dedc544b2b | Confirmed: False
# Ingested TX: a2ba5353bd1ae5b7b49aae608107fb86669efe1efdcf31bc785c33cecd79a033 | Confirmed: False
# Ingested TX: 2e7a6c6b0dce9fad9df070979a70498eb2e6149dbac1d923dd1d22033990f420 | Confirmed: False
# Ingested TX: 51b6b04d5ee9adb37b36dbe7bbc21baed3a8e7f7482b0cf14837d22494609865 | Confirmed: False
# Ingested TX: a1dca1ebe4540c0726fa935520067251bf04437e70e4c444eda751194ea4cd6f | Confirmed: False
# Ingested TX: 10a7a7e044cd7e077e43bcfa944b94cb354ea2d0aeecad4c16f1fe8a68772725 | Confirmed: False
# Ingested TX: 27f922a35fd9d3e33d20d767a259d5439371cee0b91c507f4d7b1771e0ddaee0 | Confirmed: False
# Ingested TX: f2f28e14552b3230cee9768c49d15c5781eb84e0991321c8a3af5bd03c0bc0b8 | Confirmed: False
# Ingested TX: ab2e3f8f8e3344834f0cade541c7b57b9c577534d1071968d41c999f1e0d7fa0 | Confirmed: False
# Ingested TX: efc47756d7eb5612568a2ea46618a497713d2550ac6919840e3fdb669607d226 | Confirmed: False
# Ingested TX: 1e9c8ab1de9d5fcdf9e1dcaa6f7eadf92f288fed71a0aab6f5f792ead3674b47 | Confirmed: False
# Ingested TX: 2d7bdf7431c8535877feef1b9b1428e11748d0ae6b40237ebc635922fa346738 | Confirmed: False
# Ingested TX: 36f6329b46f6d03242f5e12271e2ffae866f425e8374faff93836d85ea961155 | Confirmed: False
# Ingested TX: 482ab51b004f8331dd19c5524ee2e18df501b11b9f2898aed0a2a3a2a6ec83e7 | Confirmed: False
# Ingested TX: e21345237b701473a8221fb3daaa57ea99979f7d69f48ab3f6d359819c8df717 | Confirmed: False
# Ingested TX: 9193ee334754d0fde6d3609892097fe9daa566ada0f9097ddbae1ff824619e2a | Confirmed: False
# Ingested TX: ca9c148d47e2e79bd54a75d86c5435de6fe2e46c2039f35831064f20fe797a79 | Confirmed: False
# Ingested TX: 8ee6bcb8fedaf95e9f5094b519c39d0909022a09f9bb7b54c556617c5f2ed0fd | Confirmed: False
# Ingested TX: bcd90e01c352580902d903cf5a208c45d0af30727df0369a2129b25214debbe7 | Confirmed: False
# Ingested TX: dd93ca6fd81e14bcfb446adfcca48aea49042855d40102bcac808645d4c86d56 | Confirmed: False
# Ingested TX: dc22910c86f9eef613439bfae4ca9f894a0db2c525237f900a55eb358143079c | Confirmed: False
# Ingested TX: 65636700a69d1a8d418b3ae9ee5f02997c45c40425616807f7d69bc39bcce5ad | Confirmed: False
# Ingested TX: 8aedbaae730868a51dfb6ac8bf6e64f55f99199e9c4f453bb6d59b7eb9e9f451 | Confirmed: False
# Ingested TX: 0aa0ddc5afe1b05d4d4d4e67f1273d78c6b9bc96d8db5a8f83f1a63bda73adc5 | Confirmed: False
# Ingested TX: c0f3674741629b57f5b406fdc3fdc15e6dddbbccb12c8e735cc5b0205a9018fb | Confirmed: False
# Ingested TX: 359e1506953b88212f24a29692b26b9ebae8bf3702f82029d7a341df44c2a8fd | Confirmed: False
# Ingested TX: a5eaf7944ef27e9cf5c4302d8aa491e5fe5be56142cdd71198ad5d80f950bc43 | Confirmed: False
# Ingested TX: bbc1b1d7996b813a177b067036dd5a62b1ce5622e08010eff892d5865135b745 | Confirmed: False
# Ingested TX: 938b2f57b238245b91c4662b706822929a2efd69ab176e66bfa5cbd135010821 | Confirmed: False
# Ingested TX: 53017f19d411195d1fd9fbee5325c0babce3373299f22f036d139963ab50a2be | Confirmed: False
# Ingested TX: 76517d0dc62c72a6f0ba3cdd511d65330df22fc6ca358bcfc63d1e4bfdec14b2 | Confirmed: False
# Ingested TX: 66a0d57f874fc38be8ca338f3b0951f883b01d92d86fa382b8737b315512dac6 | Confirmed: False
# Ingested TX: a4b53b0fc43825163482591c65e0bda2b94b93bd351ce4563c510ec2f4182c18 | Confirmed: False
# Ingested TX: 830c199fc15130324537af19685c2f61d526a153b4c444c60d0e53a8af15480f | Confirmed: False
# Ingested TX: 0dd54c87cfaafa054db440c97375905f564d1c8b2d797635d0fac2450e2019cc | Confirmed: False
# Ingested TX: 5be08312aebe40984653101efa9358c1526506ca914f397af4bf7a5c1ad5952b | Confirmed: False
# Ingested TX: 2ec0d18c8cf082a3a6dae995ee50349c42487974629974d02923006858e76d59 | Confirmed: False
# Ingested TX: ce089477f75d568480d7bf475de74f557ba4b3d783473b4d63bd308660e9b4c6 | Confirmed: False
# Ingested TX: 7cb1024856bd0e668dd186f245a72e44c11ae536bcaefe951b5e44bcdae80c16 | Confirmed: False
# Ingested TX: d161d51d81dc5cb8dfd325493c15385f09dfe199cfc26a1380ab1dd386d723c9 | Confirmed: False
# Ingested TX: 9cca4d1b3d99a4f3badc7d7f52e9520d358f1d87709eab8cdfa94c44eccc8258 | Confirmed: False
# Ingested TX: 6d4458daa5b66ffa7ef031a15520c03d63b37a1e90aca365c0fe3837ac6902c3 | Confirmed: False
# Ingested TX: 2f4a61f99ef71978553817dc4eed6ba61e663391522699490b543c4fcd060e7f | Confirmed: False
# Ingested TX: 5b900f0eab422d3ac734a6957c740015aa461dc99823915505ceb0a6d238e3fc | Confirmed: False
# Ingested TX: 9af4effaec9e81c83a40382ddfb2aa116b0a127223a16f55d16584d81eb3547c | Confirmed: False
# Ingested TX: a21ab53abb171bc8c261fcadc6aa59284523de34e7a051685dd7077820812735 | Confirmed: False
# Ingested TX: fa284289560c6d091edd04ba1ba6b634bc3b3c874e7b4c6cee5ed44157d616bd | Confirmed: False
# Ingested TX: 9e846c984eaec5612e416dee800eac028ea61a79216fbe5ebe1d45f5ee336eb6 | Confirmed: False
# Ingested TX: 2458121a104cff6fa77d19e71baa09a15236579f51505adcf07e1913c230f8ed | Confirmed: False
# Ingested TX: e2edb5074a0ae108cc4aa9cc878dd0756f8963da99afd951823270cba920c905 | Confirmed: False
# Ingested TX: ad5bf1dec5ae35413fb8202cfd034b6fad78ba93482b78780e43af0caf621e96 | Confirmed: False
# Ingested TX: b5e1442075bc68fe8ffb6c3f25a2b3901c8b3e2d2619b7e30fe592271fb22759 | Confirmed: False
# Ingested TX: c5ffbb7dae671abfe3e56872fda69f9fbdcf3ae969b6789bce17fda5cb119fda | Confirmed: False
# Ingested TX: 769f170fe41b38b8fa9deaa7fe9b770bc3e963c13cc88660c44fb9147d50d9e6 | Confirmed: False
# Ingested TX: 9f6ac8b3f0361829c9ed3cc48b8bb4cbd9f21f6731baddc16b2caa228922ae65 | Confirmed: False
# Ingested TX: 8e84f838fbe47aadb8230dca7d7aad0a7dd7166baaed493c4447ecf9d552a594 | Confirmed: False
# Ingested TX: 38251c4bb04b84665c0344e1d391c8cab1d3a3a287fdf608e6556c20ed003476 | Confirmed: False
# Ingested TX: aeee880c0e7d124bdcd9bf8d282e646af3148fa7217f09acd1b1065d7981ab25 | Confirmed: False
# Ingested TX: 653058cb22c1465c7d5db87e5a1daacdfa8af8c6311b73dc808dc5d8f837c71e | Confirmed: False
# Ingested TX: 5efeaa0d8ce7c1d7397fe4745be4f3417482ea35114c6bbc0e1aa23793c20cc1 | Confirmed: False
# Ingested TX: 72d15014a8e07e87ec0997397c42c5c2d62b17b7b4aea1acf901df09907e7f77 | Confirmed: False
# Ingested TX: 67f8f3d4bfd45817692106ac82e37d04ed9d91354b6bfe3ee252990260e9feef | Confirmed: False
# Ingested TX: df1229cc37a6da87eb645c14d677f2273bdf1e1cf48f7e1692cd60ce2076a113 | Confirmed: False
# Ingested TX: 10f2e2a7d15f7b89497a1ef16b6f00e39b74d7c6630ccbe06f49fde290af6e40 | Confirmed: False
# Ingested TX: 6298dfd9af60ea2891d4f648a34f9d4b586ced725e0ce5ee5346f169492a58db | Confirmed: False
# Ingested TX: f6c785a03315e56c9a2a32c9afcb6e435e82250d5d3a49c2a09db015763a2e98 | Confirmed: False
# Ingested TX: ba304bc4122d5e632f126856984191ad18407931b23cfa2c4357dff5216e37aa | Confirmed: False
# Ingested TX: 7a8f5b1aa76b1a85538c22f19268e0b8c55e6d7694fb5b60c041a86b3ba09f88 | Confirmed: False
# Ingested TX: fbe0d85179d9f4b029f7d4603106a9ed896b7dc8a6179a2b9ba504433c66eaed | Confirmed: False
# Ingested TX: 805dc0fa0b0778c1f833940007757a8a2f57543019daf1c6081feb7f7fb49bde | Confirmed: False
# Ingested TX: 5011ee14b1463ae86182d8911d67244992da2bf0874ec89e17cba62fb1d80e22 | Confirmed: False
# Ingested TX: 6782eb0d3e9560f62f4c478ead4cb9463d9bbcb348862326f136970a2639a2d2 | Confirmed: False
# Ingested TX: 443d71ace29a1088215139ac548fd40152fd226c4f32fc12b6195bee9a7587a8 | Confirmed: False
# Ingested TX: ae8ddb2895aefef6cc9e570876361e79dec69b38eaf9515309c67c6ad0c10891 | Confirmed: False
# Ingested TX: 331a67f55c1ec56fbe452771979b86e9422b247ac315db12e274121fbc312e7e | Confirmed: False
# Ingested TX: 257327495a663ba596673b28599ec1c23ad4cd82056eae3c62d39da7756de469 | Confirmed: False
# Ingested TX: 62188cccc3641eb90ae35c870536fb4004dde68c4da6d198b97c6e3af9cd5d8b | Confirmed: False
# Ingested TX: cf2af2871f928a937c74fe02b0f78cf897b39f196a88842464c90ca3accc62b3 | Confirmed: False
# Ingested TX: be0a09699db2884a630444b83a2fa087ac7d066bd88ac14d8fb7de35612e2a5b | Confirmed: False
# Ingested TX: a4e0a02552edf465b588759839dad0e35307692e9d4c06aa928bfecae2ae8eb6 | Confirmed: False
# Ingested TX: 5f9076221566f6b72026845b7b39cc28e9b0a612514d0c0fc865e8339a85c8c0 | Confirmed: False
# Ingested TX: d31d167fb8f2cd04ac76005efb05d4f49212bc747da027ef2f0773f000fd000c | Confirmed: False
# Ingested TX: 34b3341665a8c82b2043dd3c2051c22a0afd0942e11e1436af725a141429ac8f | Confirmed: False
# Ingested TX: ffae4958676f50d32a19073652df32dbb6c6e114132a90011da77ff87bb50a04 | Confirmed: False
# Ingested TX: 79bb3efed720b4e0cac46b21c1c7319916f71206e65aa789c461f862a1048fcb | Confirmed: False
# Ingested TX: e345105d57dc177d5033b0f1446dd6f38a2f4e2f596a5c4be66f32ecbd7d1ab6 | Confirmed: False
# Ingested TX: b40aa9bcf2d793ec13f430533d7561f335f0d3e1d4248fcd58c2e8d69b2af7be | Confirmed: False
# Ingested TX: 10e182ff67efdd29456dc0aa88ae08297e37210ebd185c5901ec6f2edef4842c | Confirmed: False
# Ingested TX: 948f234405ffbd53fcc3ecc91e17a0d2aa5b45c5f5e0a03c676ac86d8b12734c | Confirmed: False
# Ingested TX: 4fc1da41681e5728ba411ca92e12e9bdd1937536270c873005faa5ad4d4cd144 | Confirmed: False
# Ingested TX: afe8b26f7f431ae61f8e0721a052e091f87601dc7501c3301d5bc6fb4faf5cab | Confirmed: False
# Ingested TX: 756caadbe4e1aab74e276a5a098ee76173ab09dce580e0caf996d33f128d033e | Confirmed: False
# Ingested TX: 0a5b5fe0454fbae3a6559ed4bd9be69f96d8d033e478cacdba1bd213bd450400 | Confirmed: False
# Ingested TX: e54fbb1f480533b72b078b1c93e4e9e10fcad73824f0f9b3a2f4c0c82861f9bb | Confirmed: False
# Ingested TX: 8b4e447c5c039aa597d41deb00c6538ec751718dead0bb188c53ba9fb472302d | Confirmed: False
# Ingested TX: fa322d0018d77a25b5c393f477d72b464e27fde7eb0b947651f072f931b88a3e | Confirmed: False
# Ingested TX: 04fc57a7a09ffb8701629735f4afbcda101db844e9678b1beb307420eac3cd26 | Confirmed: False
# Ingested TX: 394b6830f3b600978af23803db4f71a131dfaec4bc6e0b1d66245dab17732642 | Confirmed: False
# Ingested TX: e2546b3d34579fc1bd88d90aa5d6f6702e70a60aa445b91cde305cd7ef20d441 | Confirmed: False
# Ingested TX: 97bd667f2ee663fd5e014ca537f880f21b6ac1a4b434da90d9ecc341ba9eccb0 | Confirmed: False
# Ingested TX: b9a77173f82c6ac9fc6d2eeb6a7b82896b3e0ee4a2cd226047aa68cd21058c52 | Confirmed: False
# Ingested TX: a354bded352f0bca8e4bcd84bfffe297770569bea0dcb5efb38f8eb82cd9209c | Confirmed: False
# Ingested TX: 1b357333a38471a2741ce02016dbd1c618b5d202770a7b768fd344ffbed933ef | Confirmed: False
# Ingested TX: 949e42725deacdb9609a1603663ffdf9af9334018cf934a8d5fdc9bcfbe8e8b1 | Confirmed: False
# Ingested TX: be110e8c1c6ca0d0cb0edacac3c1eeb8bc81ec27b52ff327ede7103d290490d8 | Confirmed: False
# Ingested TX: 405ba998dcd7514076fd6cab06e6d753313e9f2017bdb2aff8dd4bac0a6c242a | Confirmed: False
# Ingested TX: fdafeebbb9b82a9d190daded24a3e467761c93c3d2dfa3fd489f13586b149d00 | Confirmed: False
# Ingested TX: ff65105f1937155c932cd7bb914f8514e2d1d8d9aa679f919b060d94bc61a48c | Confirmed: False
# Ingested TX: 8fd77ff570355105804dc183a2d8ced1462d85c69b05fcf33965e5b7b4f09302 | Confirmed: False
# Ingested TX: 290d7b4f68a30337f8e1c6e1b1080345698858840ea732d792d5aefdf1dbca4b | Confirmed: False
# Ingested TX: 3fa561facaf9e29ef9d66831534ce476ddb0b355138b396ab0a8e4b740304391 | Confirmed: False
# Ingested TX: 105489255cb350efe953047f161b7176c8e0be9d9c0a3b77a73ae9eb41480120 | Confirmed: False
# Ingested TX: 498539bde9d7b225cc4f22de8a04c7e9d6b491b05707f4fa1b0692dc5dae5d34 | Confirmed: False
# Ingested TX: 67c848466361c92e78f495eafcc9544eee1390639a2328d4c323f3b9469a807d | Confirmed: False
# Ingested TX: 4a3dcb5cd61ebaebe2134f3ecf707b6834f953e9a23a1019402e56546f4917be | Confirmed: False
# Ingested TX: e6c96892b99f932884f06e3b9f44d3b93c3a2cfc261e6f7ca23a77ad925e4c40 | Confirmed: False
# Ingested TX: 355b2d422f37a82a6d479c064d27874d47f4aa663abf85c8ac894573d3286723 | Confirmed: False
# Ingested TX: fbbd6de2dc7080d21e40059133f96e9f8d91c5755d41157236e0e8dd234b3a8d | Confirmed: False
# Ingested TX: dc56285028383eb2bf942ec56ed604c92d90a49b69684384623bc73915e40202 | Confirmed: False
# Ingested TX: 42dc7103d24e57d76a07d481cf7190dd472a251b7451e46178c235f99079abf6 | Confirmed: False
# Ingested TX: aa0fe1586fbe38ec32bfd53c7625f8d2677f610c9c6aafb26ee4aa29f1796f60 | Confirmed: False
# Ingested TX: 74ddf9a54fff30665e02380a458b94c141acf0dc54fc80e0d3d0b74b003c67ff | Confirmed: False
# Ingested TX: 9381fce6f82eb6dca597c78862d3f6a2c5cffed6ac6f7d9b453dc7aeed5ef5b3 | Confirmed: False
# Ingested TX: 95e3e32e84bad0c7046c648e9f2fdcc4b61bd563784c42370f2327727d776102 | Confirmed: False
# Ingested TX: 013da0bb9b0d1bd13d4a847211e579a47868b1dec379cf89a5d4a8358294c247 | Confirmed: False
# Ingested TX: 8a5a467d5281b1c2e0c3724fac643ce2f2ff99b342affba1842ab09944ce7bb3 | Confirmed: False
# Ingested TX: 5aca5e2747d1ec25c18fea8dd71ffd253dc6e8de25dc4a359c091a12d1ce0d75 | Confirmed: False
# Ingested TX: 11765cf49ec185813d23c55c8e71b75457a54f7c130dcb58ee97459bca6c2644 | Confirmed: False
# Ingested TX: fb158c4bf351bd68de296475956da1f27a5438a1a10acc62f5edbe06720f93c6 | Confirmed: False
# Ingested TX: d92670207f73fb8da81e2275bdd3fb1e4df406f26931b72afb784116a3a2f564 | Confirmed: False
# Ingested TX: 1808b5162a242e55f3e9a60576cc3775aa8f71193569408ea5454cbf9c766ddc | Confirmed: False
# Ingested TX: 04c0188b68f982d14b338a58611bbf1e5b1de792c77d7fce8ac6eb54846f29ba | Confirmed: False
# Ingested TX: 383049c193bbd7897fc8a3c9f4ef1b99e379ee6982219caff66ae3c58ba499fc | Confirmed: False
# Ingested TX: 85c06e1bfc55fe40e341be82efd34e46dfc4fa7a4edcad5208b6b8193eb26cd9 | Confirmed: False
# Ingested TX: 59fd0b4a8ef7db0fb6893113078b9e80265f4453346458bca8ae83d2d0c5f8ac | Confirmed: False
# Ingested TX: d95982904f6c32fea5432b045466ac6b4424d166bdcdab269083728c943cb32e | Confirmed: False
# Ingested TX: 2a09d38cc0a07208a774f414675dec886f4117eba04a20938410a8a22c6c9206 | Confirmed: False
# Ingested TX: b35c3515df1f94882e2022d98bd48bd9fd003cb29ebcf826b8b028baea74f29a | Confirmed: False
# Ingested TX: e67e523b6dd073dc8a60b47975f38d2b45767655e75de07f9220cebefcd3a589 | Confirmed: False
# Ingested TX: c0bf56a803203bcb457bd95f6ff13ea5f77c67fb8657e01366b9ed509777e62f | Confirmed: False
# Ingested TX: 91ad7aba9e188e3928200ac09f7b6555ab56fb4c370d257eda1a6c958dae398d | Confirmed: False
# Ingested TX: 9ebd6a8f072d66915402a001ab03273512933de74ee51792b5beea9e1dc943d8 | Confirmed: False
# Ingested TX: 43d6e411e4cd2ba20f49e82e8f2cb54efc980ce08298c0eca2d9a9936e2d6b8d | Confirmed: False
# Ingested TX: 54b25ce0d93c8fa82ce1ea2c1fce1b44502a177bc31ce643451495cb6a4d57a1 | Confirmed: False
# Ingested TX: b3f8457912525dff8f726df6f8e4b5c8716cdaf781c9e28ac555d2eface90e64 | Confirmed: False
# Ingested TX: 98438591a08d8cf42e8aec37e2ee958b2b509846bc3c356d5c755ae56de00e93 | Confirmed: False
# Ingested TX: adeffa7540da429a5dba342f96a31ffbd35065951f8064f48cb81b925864a594 | Confirmed: False
# Ingested TX: 67e507c0575d419d26bcdf30c962319f294e0261869e036bdfee86ce34e8fb43 | Confirmed: False
# Ingested TX: 32f4e5960b1b10e2bd193cc8e9231e758f3f8c685da1059eeaaf428d84026cca | Confirmed: False
# Ingested TX: 2364ca41cad4e631ca47d5c6526467f06d9b2af04de6f195c723a79cf4e0dee0 | Confirmed: False
# Ingested TX: f9d5cd4962ad5e3754aa820ae294382cd6105d1b5e8ec16e0a4de9ac3932fb80 | Confirmed: False
# Ingested TX: 2c539a593e0219aa5de6aca6edfa5d5a725b581246240be6e1978e7c80ff9eb7 | Confirmed: False
# Ingested TX: ee6c5f7e140d1076d66ab0ac2a6847329d9e6f4857e665583614d761fcdcadbb | Confirmed: False
# Ingested TX: ed234b989274a4f9e91cedf7f72280f74b02c36319fe4e7e205fb532396c75b9 | Confirmed: False
# Ingested TX: 590e44ee0fada63174b35ab87c19ea41d2d0a5184126ad6161aeb65f42feb0aa | Confirmed: False
# Ingested TX: 40bab99112e5804544e14c0555b37c0e12e8f588baba0e64e574b91835e08a13 | Confirmed: False
# Ingested TX: e0953e8e6df0c6cb2fd04d211fe30c491a6fbbee60012001c9edb0cfa45f39ce | Confirmed: False
# Ingested TX: 1fbfdd456824b9ee7b83b0f269cc9b81a55290f250ca7a67285120bac1c39067 | Confirmed: False
# Ingested TX: b64651ac38ee8540635f39ecaadd2145be7f7d0114eaaff3035790312a9478c7 | Confirmed: False
# Ingested TX: 99eb550ed5c14791d87cf77779e901f30e8ddd520ba14add25df070c63a14ea2 | Confirmed: False
# Ingested TX: 1fc1fbf4aabaf41b2d443e91050fb5403f75880a015ab306999ce90d203f9741 | Confirmed: False
# Ingested TX: beff17aad09fef084f4861f310a33f9e342255ddb338d23daa419b1d66fb44d6 | Confirmed: False
# Ingested TX: ea06cfd2b74d9ef32952fe1d55f044713bfa0f75e445c60f047d3680bd3a00ca | Confirmed: False
# Ingested TX: deee600f1cb4b458aa8f4f520465e569900b5ddb44c43ecb6fb318d935aad3c6 | Confirmed: False
# Ingested TX: 36215607fa1d6aaf88ab70cff6e5e3d0b59ccd263ffa782609c06abe279f6324 | Confirmed: False
# WebSocket error:
# WebSocket closed

# %%
# Merging both the files and the temp file wil be deleted
merge_jsonl_to_master(CONFIRMED_OUTPUT_FILE, FINAL_JSON_PATH)
merge_jsonl_to_master(TMP_JSONL_PATH, FINAL_JSON_PATH)
# Out:
# Merged 1914 new transactions into bitcoin_transactions_backup.json
